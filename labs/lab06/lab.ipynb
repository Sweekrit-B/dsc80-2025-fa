# %%
# Initialize Otter
import otter
grader = otter.Notebook("lab.ipynb")

# %% [markdown]
# # Lab 6 – APIs and Web Scraping
#
# ## DSC 80, Fall 2025
#
# ### Due Date: Monday, November 10th at 11:59 PM

# %% [markdown]
# ## Instructions
#
# Welcome to the sixth DSC 80 lab this quarter!
#
# Much like in DSC 10, this Jupyter Notebook contains the statements of the problems and provides code and Markdown cells to display your answers to the problems. Unlike DSC 10, the notebook is *only* for displaying a readable version of your final answers. The coding will be done in an accompanying `lab.py` file that is imported into the current notebook, and **you will only submit that `lab.py` file**, not this notebook!
#
# Some additional guidelines:
# - **Unlike in DSC 10, labs will have both public tests and hidden tests.** The bulk of your grade will come from your scores on hidden tests, which you will only see on Gradescope after the assignment deadline.
# - **Do not change the function names in the `lab.py` file!** The functions in the `lab.py` file are how your assignment is graded, and they are graded by their name. If you changed something you weren't supposed to, you can find the original code in the [course GitHub repository](https://github.com/dsc-courses/dsc80-2025-sp).
# - Notebooks are nice for testing and experimenting with different implementations before designing your function in your `lab.py` file. You can write code here, but make sure that all of your real work is in the `lab.py` file, since that's all you're submitting.
# - You are encouraged to write your own additional helper functions to solve the lab, as long as they also end up in `lab.py`.
#
# **To ensure that all of the work you want to submit is in `lab.py`, we've included a script named `lab-validation.py` in the lab folder. You shouldn't edit it, but instead, you should call it from the command line (e.g. the Terminal) to test your work.** More details on its usage are given at the bottom of this notebook.
#
# **Importing code from `lab.py`**:
#
# * Below, we import the `.py` file that's contained in the same directory as this notebook.
# * We use the `autoreload` notebook extension to make changes to our `lab.py` file immediately available in our notebook. Without this extension, we would need to restart the notebook kernel to see any changes to `lab.py` in the notebook.
#     - `autoreload` is necessary because, upon import, `lab.py` is compiled to bytecode (in the directory `__pycache__`). Subsequent imports of `lab` merely import the existing compiled python.
#
# <div class="alert alert-block alert-danger">
# <b>Note: </b> For this lab, due to system constraints, the code may take varying amounts of time to run on different machines. If you are able to submit to Gradescope and the code runs, then you have met the runtime requirements.
# </div>

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from lab import *

# %% [markdown]
# If the cell below returns a `ModuleNotFoundError`, please run `!pip install lxml` in a new cell. After `lxml` is succesfully installed, go to `kernel` then restart. Note that you will only need to run `!pip install lxml` once.

# %%
import os
import pandas as pd
import numpy as np
import requests
import bs4
import lxml

# %%
#!pip install lxml

# %% [markdown]
# ## Question 1 – Practice with HTML Tags 📎
#
# In Question 2, you'll spend plenty of time parsing HTML source code. But before you get your hands dirty trying to extract information from HTML written by other people, it is a good idea to write basic HTML code yourself. This exercise will help you better understand how the code in a `.html` file is structured.
#
# For this question, you'll create a very basic `.html` file, named `lab06_1.html`, that satisfies the following conditions:
#
# - It must have `<title>` and `<head>` tags.
# - It must also have `<body>` tags. Within the `<body>` tags, it must have:
#     - At least two headers.
#     * At least three images.
#         - At least one image must be a local file.
#         - At least one image must be linked to online source.
#         - At least one image has to have default text when it cannot be displayed.
#     * At least three references (hyperlinks) to different web pages.
#     * At least one table with two rows and two columns.
#
#
# Make sure to save your file as `lab06_1.html`, and save it in the same directory as `lab.py`. **When submitting this homework to Gradescope, make sure to also upload `lab06_1.html` along with the local image that you embedded in your site.** You can upload multiple files to Gradescope at a time.
#
#
# ***Notes***:
# - You can write and view basic HTML with a Jupyter Notebook, using either a Markdown cell or by using the `IPython.display.HTML` function (which takes in a string of HTML and renders it).
# - If you write your HTML code within a Jupyter Notebook, you should later copy your code into a text editor and save it with the `.html` extension. You could also write your HTML in a text editor directly.
# - Be sure to open your final `.html` file in a browser and make sure it looks correct on its own.

# %%
# Don't delete this cell!
question1()

# %%
grader.check("q1")
# Out:
# q1 results: All test cases passed!

# %% [markdown]
# ## Question 2 – Scraping an Online Bookstore 📚
#
# Browse through the following fake online bookstore: http://books.toscrape.com/. This website is meant for toying with scraping.
#
# Your job is to scrape the website, collecting data on all books that have:
# - **_at least_ a four-star rating**, and
# - **a price _strictly_ less than £50**, and
# - **belong to specific categories** (more details below).
#
# You will extract the information into a DataFrame that looks like the one below.
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>UPC</th>
#       <th>Product Type</th>
#       <th>Price (excl. tax)</th>
#       <th>Price (incl. tax)</th>
#       <th>Tax</th>
#       <th>Availability</th>
#       <th>Number of reviews</th>
#       <th>Category</th>
#       <th>Rating</th>
#       <th>Description</th>
#       <th>Title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>e10e1e165dc8be4a</td>
#       <td>Books</td>
#       <td>Â£22.60</td>
#       <td>Â£22.60</td>
#       <td>Â£0.00</td>
#       <td>In stock (19 available)</td>
#       <td>0</td>
#       <td>Default</td>
#       <td>Four</td>
#       <td>For readers of Laura Hillenbrand's Seabiscuit...</td>
#       <td>The Boys in the Boat: Nine Americans...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>c2e46a2ee3b4a322</td>
#       <td>Books</td>
#       <td>Â£25.27</td>
#       <td>Â£25.27</td>
#       <td>Â£0.00</td>
#       <td>In stock (19 available)</td>
#       <td>0</td>
#       <td>Romance</td>
#       <td>Five</td>
#       <td>A Michelin two-star chef at twenty-eight, Violette...</td>
#       <td>Chase Me (Paris Nights #2)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>00bfed9e18bb36f3</td>
#       <td>Books</td>
#       <td>Â£34.53</td>
#       <td>Â£34.53</td>
#       <td>Â£0.00</td>
#       <td>In stock (19 available)</td>
#       <td>0</td>
#       <td>Romance</td>
#       <td>Five</td>
#       <td>No matter how busy he keeps himself...</td>
#       <td>Black Dust</td>
#     </tr>
#   </tbody>
# </table>
#
# To do so, implement the following functions.
#
# <br>
#
# #### `extract_book_links`
#
# Complete the implementation of the function `extract_book_links`, which takes in the content of a page that contains book listings as a **string of HTML**, and returns a **list** of URLs of book-specific pages for all books with **_at least_ a four-star rating and a price _strictly_ less than £50**.
#
# For this method, the URLs you return should not contain the protocol (i.e. `'https://'`). The protocols should be added back into the URLs when you actually make the requests.
#
#
# <br>
#
# #### `get_product_info`
#
# Complete the implementation of the function `get_product_info`, which takes in the content of a book-specific page as a **string of HTML**, and a list `categories` of book categories. If the input book is in the list of `categories`, `get_product_info` should return a dictionary corresponding to a row in the DataFrame in the image above (where the keys are the column names and the values are the row values). If the input book is not in the list of `categories`, return `None`. <b> The order of the dictionary keys does not matter. </b>
#
#
# <br>
#
# #### `scrape_books`
#
# Finally, put everything together. Complete the implementation of the function `scrape_books`, which takes in an integer `k` and a list `categories` of book categories. `scrape_books` should use `requests` to scrape the first `k` pages of the bookstore and return a DataFrame of only the books that have:
# - **_at least_ a four-star rating**, and
# - **a price _strictly_ less than £50**, and
# - **a category that is in the list `categories`**.
#
# <b> The order of the DataFrame columns does not matter. </b>
#
# <br>
#
# Some general guidance and tips:
#
# - The first page of the bookstore is at http://books.toscrape.com/catalogue/page-1.html. Subsequent pages can be found by clicking the "Next" button at the bottom of the page. Look at how the URLs change each time you navigate to a new page; think about how to use f-strings (or some other string formatting technique) to generate these URLs.
# - Use "inspect element" to view the source code of the pages you're trying to scrape. To find a book's category, look at the hyperlinks in the book-specific page for that book.
# - **`scrape_books` should run in under 180 seconds on the entire bookstore (`k = 50`). `scrape_books` is also the only function that should make `GET` requests; the other two functions parse already-existing HTML.**
# - When instantiating `bs4.BeautifulSoup` objects, use the optional argument `features='lxml'` to suppress any warnings.
# - Don't worry about typecasting, i.e. it's fine if `'Number of reviews'` is not stored as type `int`. Also, don't worry if you run into encoding errors in your price columns (as the example DataFrame at the top of this cell contains).

# %%
# Part 1 rough work
soup = bs4.BeautifulSoup(open(extract_book_links_fp, encoding='utf-8').read())
res = []
for product_pod in soup.find_all('article', class_='product_pod'):
    price = float(product_pod.find('p', class_='price_color').text[1:])
    rating = product_pod.find('p').get('class')[1]
    if rating in ['Four', 'Five'] and price < 50:
        res.append(product_pod.find('a').get('href'))
res
# Out:
# ['seven-brief-lessons-on-physics_219/index.html',
#  'scarlet-the-lunar-chronicles-2_218/index.html',
#  'saga-volume-3-saga-collected-editions-3_216/index.html',
#  'running-with-scissors_215/index.html',
#  'rise-of-the-rocket-girls-the-women-who-propelled-us-from-missiles-to-the-moon-to-mars_213/index.html',
#  'ready-player-one_209/index.html']

# %%
# Part 2 rough work
soup = bs4.BeautifulSoup(open(get_product_info_fp, encoding='utf-8').read())
category = soup.find('ul', class_='breadcrumb').find_all('a')[-1].text
product_type = soup.find('ul', class_='breadcrumb').find_all('a')[1].text
upc = soup.find('th', string='UPC').find_next_sibling('td').text
price_excl_tax = soup.find('th', string='Price (excl. tax)').find_next_sibling('td').text
price_incl_tax = soup.find('th', string='Price (incl. tax)').find_next_sibling('td').text
tax = soup.find('th', string='Tax').find_next_sibling('td').text
availability = soup.find('th', string='Availability').find_next_sibling('td').text
num_reviews = soup.find('th', string='Number of reviews').find_next_sibling('td').text
rating = soup.find('p', class_='star-rating').get('class')[1]
description = soup.find('div', id='product_description').find_next_sibling('p').text
title = soup.find('div', class_='product_main').find('h1').text
# Out:
# 'Frankenstein'

# %%
# Part 3 rough work
def extract_book_links(text):
    soup = bs4.BeautifulSoup(text)
    res = []
    for product_pod in soup.find_all('article', class_='product_pod'):
        price = float(product_pod.find('p', class_='price_color').text.strip()[2:])
        rating = product_pod.find('p').get('class')[1]
        if rating in ['Four', 'Five'] and price < 50:
            res.append(product_pod.find('a').get('href'))
    return res

def get_product_info(text, categories):
    soup = bs4.BeautifulSoup(text)
    category = soup.find('ul', class_='breadcrumb').find_all('a')[-1].text.strip()
    if category in categories:
        product_type = soup.find('ul', class_='breadcrumb').find_all('a')[1].text.strip()
        upc = soup.find('th', string=lambda x: x.strip() == 'UPC').find_next_sibling('td').text.strip()
        price_excl_tax = soup.find('th', string=lambda x: x.strip() == 'Price (excl. tax)').find_next_sibling('td').text.strip()
        price_incl_tax = soup.find('th', string=lambda x: x.strip() == 'Price (incl. tax)').find_next_sibling('td').text.strip()
        tax = soup.find('th', string=lambda x: x.strip() == 'Tax').find_next_sibling('td').text.strip()
        availability = soup.find('th', string=lambda x: x.strip() == 'Availability').find_next_sibling('td').text.strip()
        num_reviews = soup.find('th', string=lambda x: x.strip() == 'Number of reviews').find_next_sibling('td').text.strip()
        rating = soup.find('p', class_='star-rating').get('class')[1]
        description = soup.find('div', id='product_description').find_next_sibling('p').text.strip()
        title = soup.find('div', class_='product_main').find('h1').text.strip()
        return {
            'UPC': upc,
            'Product Type': product_type,
            'Price (excl. tax)': price_excl_tax,
            'Price (incl. tax)': price_incl_tax,
            'Tax': tax,
            'Availability': availability,
            'Number of reviews': num_reviews,
            'Category': category,
            'Rating': rating,
            'Description': description,
            'Title': title
        }
    return None

def download_page_num(i):
    url = f'http://books.toscrape.com/catalogue/page-{i}.html'
    request = requests.get(url)
    return bs4.BeautifulSoup(request.text)

def download_page_book(suffix):
    url = f'http://books.toscrape.com/catalogue/{suffix}'
    request = requests.get(url)
    return bs4.BeautifulSoup(request.text)

links = extract_book_links(download_page_num(1).prettify())
for link in links:
    print(get_product_info(download_page_book(link).prettify(), ['Mystery']))
# bs4.BeautifulSoup(download_page_book(links[0]).prettify()).find_all('th', string=lambda x: x.strip() == 'UPC')
# Out:
# {'UPC': 'e00eb4fd7b871a48', 'Product Type': 'Books', 'Price (excl. tax)': 'Â£47.82', 'Price (incl. tax)': 'Â£47.82', 'Tax': 'Â£0.00', 'Availability': 'In stock (20 available)', 'Number of reviews': '0', 'Category': 'Mystery', 'Rating': 'Four', 'Description': 'WICKED above her hipbone, GIRL across her heart Words are like a road map to reporter Camille Preakerâ\x80\x99s troubled past. Fresh from a brief stay at a psych hospital, Camilleâ\x80\x99s first assignment from the second-rate daily paper where she works brings her reluctantly back to her hometown to cover the murders of two preteen girls. NASTY on her kneecap, BABYDOLL on her leg Since WICKED above her hipbone, GIRL across her heart Words are like a road map to reporter Camille Preakerâ\x80\x99s troubled past. Fresh from a brief stay at a psych hospital, Camilleâ\x80\x99s first assignment from the second-rate daily paper where she works brings her reluctantly back to her hometown to cover the murders of two preteen girls. NASTY on her kneecap, BABYDOLL on her leg Since she left town eight years ago, Camille has hardly spoken to her neurotic, hypochondriac mother or to the half-sister she barely knows: a beautiful thirteen-year-old with an eerie grip on the town. Now, installed again in her familyâ\x80\x99s Victorian mansion, Camille is haunted by the childhood tragedy she has spent her whole life trying to cut from her memory. HARMFUL on her wrist, WHORE on her ankle As Camille works to uncover the truth about these violent crimes, she finds herself identifying with the young victimsâ\x80\x94a bit too strongly. Clues keep leading to dead ends, forcing Camille to unravel the psychological puzzle of her own past to get at the story. Dogged by her own demons, Camille will have to confront what happened to her years before if she wants to survive this homecoming.With its taut, crafted writing, Sharp Objects is addictive, haunting, and unforgettable. ...more', 'Title': 'Sharp Objects'}
# None
# None
# None
# None
# None

# %%
# don't delete this cell, but do run it -- it is needed for the autograder tests

# public test for extract_book_links 
extract_book_links_fp = os.path.join('data', 'products.html')
extract_book_out = extract_book_links(
    open(extract_book_links_fp, encoding='utf-8').read()
)
extract_book_url = 'scarlet-the-lunar-chronicles-2_218/index.html'

# doc tests for get product info
get_product_info_fp = os.path.join('data', 'Frankenstein.html')
get_product_info_out = get_product_info(
    open(get_product_info_fp, encoding='utf-8').read(), ['Default']
)

# public test for scrape books 
scrape_books_out = scrape_books(1, ['Mystery'])
scrape_books_out
# Out:
# c:\Users\sweek\Downloads\ucsd\ucsd_classes\fa25\dsc80\dsc80-2025-fa\labs\lab06\lab.py:81: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 81 of the file c:\Users\sweek\Downloads\ucsd\ucsd_classes\fa25\dsc80\dsc80-2025-fa\labs\lab06\lab.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
# c:\Users\sweek\Downloads\ucsd\ucsd_classes\fa25\dsc80\dsc80-2025-fa\labs\lab06\lab.py:37: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 37 of the file c:\Users\sweek\Downloads\ucsd\ucsd_classes\fa25\dsc80\dsc80-2025-fa\labs\lab06\lab.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   soup = bs4.BeautifulSoup(text)
# c:\Users\sweek\Downloads\ucsd\ucsd_classes\fa25\dsc80\dsc80-2025-fa\labs\lab06\lab.py:86: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 86 of the file c:\Users\sweek\Downloads\ucsd\ucsd_classes\fa25\dsc80\dsc80-2025-fa\labs\lab06\lab.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
# c:\Users\sweek\Downloads\ucsd\ucsd_classes\fa25\dsc80\dsc80-2025-fa\labs\lab06\lab.py:47: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 47 of the file c:\Users\sweek\Downloads\ucsd\ucsd_classes\fa25\dsc80\dsc80-2025-fa\labs\lab06\lab.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   ...
#                 UPC Product Type Price (excl. tax) Price (incl. tax)     Tax  \
# 0  e00eb4fd7b871a48        Books           Â£47.82           Â£47.82  Â£0.00
#
#               Availability Number of reviews Category Rating  \
# 0  In stock (20 available)                 0  Mystery   Four
#
#                                          Description          Title
# 0  WICKED above her hipbone, GIRL across her hear...  Sharp Objects

# %%
grader.check("q2")
# Out:
# q2 results: All test cases passed!

# %% [markdown]
# ## Question 3 – API Requests 🤑
#
# You trade stocks as a hobby. As an avid `pandas` coder, you decide to calculate statistics of your favorite stocks by pulling data from a public API. The API we will work with can be found at https://financialmodelingprep.com/developer/docs/#Stock-Historical-Price. Specifically, we will use the "**Daily Chart EOD**" endpoint (search for it at the linked page).
#
# Some relevant definitions:
# - Ticker: A short code that refers to a stock. For example, Apple's ticker is AAPL and Ford's ticker is F.
# - Open: The price of a stock at the beginning of a trading day.
# - Close: The price of a stock at the end of a trading day.
# - Volume: The total number of shares traded in a day.
# - Percent change: The difference in price with respect to the original price, as a percentage.
#
# To make requests to the aforementioned API, you will need an API key. In order to get one, you will need to make an account at the website. Once you've signed up, you can use the API key that comes with the free plan. It has a limit of 250 requests per day, which should be more than enough. You will have to encode your API key in the URL that you make requests to; see a complete example of such a request at the right side of the [documentation](https://site.financialmodelingprep.com/developer/docs#Stock-Historical-Price).
#
# Implement the following two functions.
#
# #### `stock_history`
#
# Complete the implementation of the function `stock_history`, which takes in a string `ticker` and two integers, `year` and `month`, and returns a DataFrame containing the price history for that stock in that month. Keep all of the attributes that are returned by the API.
#
# ***Notes***:
# - Read the API documentation if you get stuck!
# - [`pd.date_range`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.date_range.html) takes in two dates and returns a sequence of all dates between the two dates, excluding the right endpoint. How might this be helpful?
# - The [`requests.get`](https://docs.python-requests.org/en/master/user/quickstart/) function returns a Response object, not the data itself. Use the `json` method on the Response object to extract the relevant JSON, as we did in [Lecture 9](https://dsc80.com/resources/lectures/lec09/lec09-filled.html#Example:-GET-requests-via-requests) (you don't need to `import json` to do this).
# - You can instantiate a DataFrame using a sequence of dictionaries.
#
# <br>
#
# #### `stock_stats`
#
# Create a function `stock_stats` that takes in a DataFrame outputted by `stock_history` and returns a **tuple** of two numbers:
# 1. The percent change of the stock throughout the month as a **percentage**.
# 2. An estimate of the total transaction volume **in billion of dollars** for that month.
#
# Both values in the tuple should be **strings** that contain numbers rounded to two decimal places. Add a plus or minus sign in front of the percent change, and make sure that the total transaction volume string ends in a `'B'`.
#
# **To compute the percent change**, use the opening price on the first day of the month as the starting price and the closing price on the last day of the month as the ending price.
#
# **To compute the total transaction volume**, assume that on any given day, the average price of a share is the midpoint of the high and low price for that day.
#
# $$ \text{Estimated Total Transaction Volume (in dollars)} = \text{Volume (number of shares traded)} \times \text{Average Price} $$
#
# For example, suppose there are only three days in March – March 1st, March 2nd, and March 3rd.
#
# If BYND (Beyond Meat) opens at \\$4 on March 1st and closes at \\$5 on March 3rd, its percent change for the month of March is $$\frac{\$5-\$4}{\$4} = +25.00\%$$
#
# Suppose the high and low prices and volumes of BYND on each day are given below.
# - March 1st: high \\$5, low \\$3, volume 500 million (0.5 billion)
# - March 2nd: high \\$5.5, low \\$2.5, volume 1 billion
# - March 3rd: high \\$5.25, low \\$4, volume 500 million (0.5 billion)
#
# Then, the estimated total transaction volume is
# $$\frac{\$5 + \$3}{2} \cdot 0.5 B + \frac{\$5.5 + \$2.5}{2} \cdot 1 B + \frac{\$5.25 + \$4}{2} \cdot 0.5 B = 8.3125B$$

# %%
# base_url = f'https://financialmodelingprep.com/stable/historical-price-eod/full?symbol=AAPL'
# apikey = '?apikey=lXc6qZucwcvy741kF1HA6w6mRqv2inOo'
baseurl = 'https://financialmodelingprep.com/stable/historical-price-eod/full?symbol=AAPL&apikey=lXc6qZucwcvy741kF1HA6w6mRqv2inOo'
df = pd.DataFrame(requests.get(baseurl).json())
df['date'] = pd.to_datetime(df['date'])
filtered = df[(df['date'].dt.year == 2025) & (df['date'].dt.month == 6)].sort_values('date')
percent_change = (filtered.iloc[-1]['close'] - filtered.iloc[0]['open'])/(filtered.iloc[0]['open'])
if round(percent_change*100, 2) > 0:
    percent_change = '+' + str(round(percent_change*100, 2)) + '%'
else:
    percent_change = str(round(percent_change*100, 2)) + '%'
filtered['transaction_volume'] = filtered.apply(lambda df: (df['high'] + df['low'])/2 * df['volume'], axis=1)
total_transaction_volume = str(round(filtered['transaction_volume'].sum()/1_000_000_000, 2)) + 'B'
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\sweek\miniforge3\envs\dsc80\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\sweek\miniforge3\envs\dsc80\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\sweek\miniforge3\envs\dsc80\Lib\json\decoder.py:338, in JSONDecoder.decode(self, s, _w)
#     334 """Return the Python representation of ``s`` (a ``str`` instance
#     335 containing a JSON document).
#     336
#     337 """
# --> 338 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     339 end = _w(s, end).end()
#
# File c:\Users\sweek\miniforge3\envs\dsc80\Lib\json\decoder.py:356, in JSONDecoder.raw_decode(self, s, idx)
#     355 except StopIteration as err:
# --> 356     raise JSONDecodeError("Expecting value", s, err.value) from None
#     357 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[187], line 4
#       1 # base_url = f'https://financialmodelingprep.com/stable/historical-price-eod/full?symbol=AAPL'
#       2 # apikey = '?apikey=lXc6qZucwcvy741kF1HA6w6mRqv2inOo'
#       3 baseurl = 'https://financialmodelingprep.com/stable/historical-price-eod/full?symbol=BYND&apikey=lXc6qZucwcvy741kF1HA6w6mRqv2inOo'
# ----> 4 df = pd.DataFrame(requests.get(baseurl).json())
#       5 df['date'] = pd.to_datetime(df['date'])
#       6 filtered = df[(df['date'].dt.year == 2025) & (df['date'].dt.month == 6)].sort_values('date')
#
# File c:\Users\sweek\miniforge3\envs\dsc80\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# base_url = f'https://financialmodelingprep.com/stable/historical-price-eod/full?symbol=AAPL'
# apikey = '?apikey=lXc6qZucwcvy741kF1HA6w6mRqv2inOo'
baseurl = 'https://financialmodelingprep.com/stable/historical-price-eod/full?symbol=AAPL&apikey=lXc6qZucwcvy741kF1HA6w6mRqv2inOo'
requests.get(baseurl).json()
# Out:
# [{'symbol': 'AAPL',
#   'date': '2025-11-07',
#   'open': 269.8,
#   'high': 272.29,
#   'low': 266.77,
#   'close': 268.47,
#   'volume': 48279451,
#   'change': -1.32,
#   'changePercent': -0.49296,
#   'vwap': 269.3325},
#  {'symbol': 'AAPL',
#   'date': '2025-11-06',
#   'open': 267.89,
#   'high': 273.4,
#   'low': 267.89,
#   'close': 269.77,
#   'volume': 51204045,
#   'change': 1.88,
#   'changePercent': 0.70178,
#   'vwap': 269.7375},
#  {'symbol': 'AAPL',
#   'date': '2025-11-05',
#   'open': 268.61,
#   'high': 271.7,
#   'low': 266.93,
#   'close': 270.14,
#   'volume': 43683100,
#   'change': 1.53,
#   'changePercent': 0.5696,
#   'vwap': 269.345},
#  {'symbol': 'AAPL',
#   'date': '2025-11-04',
#   'open': 268.33,
#   'high': 271.49,
#   'low': 267.62,
#   'close': 270.04,
#   'volume': 49274846,
#   'change': 1.72,
#   'changePercent': 0.63727,
#   'vwap': 269.37},
#  {'symbol': 'AAPL',
#   'date': '2025-11-03',
#   'open': 270.42,
#   'high': 270.85,
#   'low': 266.25,
#   'close': 269.05,
#   'volume': 50194600,
#   'change': -1.37,
#   'changePercent': -0.50662,
#   'vwap': 269.1425},
#  {'symbol': 'AAPL',
#   'date': '2025-10-31',
#   'open': 276.99,
#   'high': 277.32,
#   'low': 269.16,
#   'close': 270.37,
#   'volume': 86167123,
#   'change': -6.62,
#   'changePercent': -2.39,
#   'vwap': 273.46},
#  {'symbol': 'AAPL',
#   'date': '2025-10-30',
#   'open': 271.99,
#   'high': 274.14,
#   'low': 268.48,
#   'close': 271.4,
#   'volume': 69886534,
#   'change': -0.59,
#   'changePercent': -0.21692,
#   'vwap': 271.5025},
#  {'symbol': 'AAPL',
#   'date': '2025-10-29',
#   'open': 269.27,
#   'high': 271.41,
#   'low': 267.11,
#   'close': 269.7,
#   'volume': 51086742,
#   'change': 0.425,
#   'changePercent': 0.15969,
#   'vwap': 269.3725},
#  {'symbol': 'AAPL',
#   'date': '2025-10-28',
#   'open': 268.99,
#   'high': 269.89,
#   'low': 268.15,
#   'close': 269,
#   'volume': 41534800,
#   'change': 0.015,
#   'changePercent': 0.00371761,
#   'vwap': 269.0075},
#  {'symbol': 'AAPL',
#   'date': '2025-10-27',
#   'open': 264.88,
#   'high': 269.12,
#   'low': 264.65,
#   'close': 268.81,
#   'volume': 44888200,
#   'change': 3.93,
#   'changePercent': 1.48,
#   'vwap': 266.865},
#  {'symbol': 'AAPL',
#   'date': '2025-10-24',
#   'open': 261.19,
#   'high': 264.13,
#   'low': 259.18,
#   'close': 262.82,
#   'volume': 38253717,
#   'change': 1.63,
#   'changePercent': 0.62407,
#   'vwap': 261.83},
#  {'symbol': 'AAPL',
#   'date': '2025-10-23',
#   'open': 259.94,
#   'high': 260.62,
#   'low': 258.01,
#   'close': 259.58,
#   'volume': 32754941,
#   'change': -0.36,
#   'changePercent': -0.13849,
#   'vwap': 259.5375},
#  {'symbol': 'AAPL',
#   'date': '2025-10-22',
#   'open': 262.65,
#   'high': 262.85,
#   'low': 255.43,
#   'close': 258.45,
#   'volume': 45015300,
#   'change': -4.2,
#   'changePercent': -1.6,
#   'vwap': 259.845},
#  {'symbol': 'AAPL',
#   'date': '2025-10-21',
#   'open': 261.88,
#   'high': 265.29,
#   'low': 261.83,
#   'close': 262.77,
#   'volume': 46695948,
#   'change': 0.89,
#   'changePercent': 0.33985,
#   'vwap': 262.9425},
#  {'symbol': 'AAPL',
#   'date': '2025-10-20',
#   'open': 255.89,
#   'high': 264.38,
#   'low': 255.63,
#   'close': 262.24,
#   'volume': 90483029,
#   'change': 6.36,
#   'changePercent': 2.48,
#   'vwap': 259.535},
#  {'symbol': 'AAPL',
#   'date': '2025-10-17',
#   'open': 248.02,
#   'high': 253.38,
#   'low': 247.27,
#   'close': 252.29,
#   'volume': 49147000,
#   'change': 4.27,
#   'changePercent': 1.72,
#   'vwap': 250.24},
#  {'symbol': 'AAPL',
#   'date': '2025-10-16',
#   'open': 248.25,
#   'high': 249.04,
#   'low': 245.13,
#   'close': 247.45,
#   'volume': 39777000,
#   'change': -0.8,
#   'changePercent': -0.32226,
#   'vwap': 247.4675},
#  {'symbol': 'AAPL',
#   'date': '2025-10-15',
#   'open': 249.49,
#   'high': 251.82,
#   'low': 247.47,
#   'close': 249.34,
#   'volume': 33893611,
#   'change': -0.145,
#   'changePercent': -0.06012265,
#   'vwap': 249.53},
#  {'symbol': 'AAPL',
#   'date': '2025-10-14',
#   'open': 246.6,
#   'high': 248.85,
#   'low': 244.7,
#   'close': 247.77,
#   'volume': 35478000,
#   'change': 1.17,
#   'changePercent': 0.47445,
#   'vwap': 246.98},
#  {'symbol': 'AAPL',
#   'date': '2025-10-13',
#   'open': 249.38,
#   'high': 249.69,
#   'low': 245.56,
#   'close': 247.66,
#   'volume': 38142942,
#   'change': -1.72,
#   'changePercent': -0.68971,
#   'vwap': 248.0725},
#  {'symbol': 'AAPL',
#   'date': '2025-10-10',
#   'open': 254.94,
#   'high': 256.38,
#   'low': 244,
#   'close': 245.27,
#   'volume': 61999100,
#   'change': -9.67,
#   'changePercent': -3.79,
#   'vwap': 250.1475},
#  {'symbol': 'AAPL',
#   'date': '2025-10-09',
#   'open': 257.81,
#   'high': 258,
#   'low': 253.14,
#   'close': 254.04,
#   'volume': 38322012,
#   'change': -3.77,
#   'changePercent': -1.46,
#   'vwap': 255.7475},
#  {'symbol': 'AAPL',
#   'date': '2025-10-08',
#   'open': 256.52,
#   'high': 258.52,
#   'low': 256.11,
#   'close': 258.06,
#   'volume': 36496900,
#   'change': 1.54,
#   'changePercent': 0.60034,
#   'vwap': 257.3025},
#  {'symbol': 'AAPL',
#   'date': '2025-10-07',
#   'open': 256.81,
#   'high': 257.4,
#   'low': 255.43,
#   'close': 256.48,
#   'volume': 31955800,
#   'change': -0.325,
#   'changePercent': -0.1285,
#   'vwap': 256.53},
#  {'symbol': 'AAPL',
#   'date': '2025-10-06',
#   'open': 257.99,
#   'high': 259.07,
#   'low': 255.05,
#   'close': 256.69,
#   'volume': 44664118,
#   'change': -1.3,
#   'changePercent': -0.5039,
#   'vwap': 257.2},
#  {'symbol': 'AAPL',
#   'date': '2025-10-03',
#   'open': 254.67,
#   'high': 259.24,
#   'low': 253.95,
#   'close': 258.02,
#   'volume': 49155614,
#   'change': 3.35,
#   'changePercent': 1.32,
#   'vwap': 256.47},
#  {'symbol': 'AAPL',
#   'date': '2025-10-02',
#   'open': 256.58,
#   'high': 258.18,
#   'low': 254.15,
#   'close': 257.13,
#   'volume': 42630239,
#   'change': 0.555,
#   'changePercent': 0.21436,
#   'vwap': 256.51},
#  {'symbol': 'AAPL',
#   'date': '2025-10-01',
#   'open': 255.04,
#   'high': 258.79,
#   'low': 254.93,
#   'close': 255.45,
#   'volume': 48713940,
#   'change': 0.41,
#   'changePercent': 0.16076,
#   'vwap': 256.0525},
#  {'symbol': 'AAPL',
#   'date': '2025-09-30',
#   'open': 254.86,
#   'high': 255.92,
#   'low': 253.11,
#   'close': 254.63,
#   'volume': 37704300,
#   'change': -0.225,
#   'changePercent': -0.09024563,
#   'vwap': 254.63},
#  {'symbol': 'AAPL',
#   'date': '2025-09-29',
#   'open': 254.56,
#   'high': 255,
#   'low': 253.01,
#   'close': 254.43,
#   'volume': 40127700,
#   'change': -0.13,
#   'changePercent': -0.05106851,
#   'vwap': 254.25},
#  {'symbol': 'AAPL',
#   'date': '2025-09-26',
#   'open': 254.1,
#   'high': 257.6,
#   'low': 253.78,
#   'close': 255.46,
#   'volume': 46076300,
#   'change': 1.37,
#   'changePercent': 0.53522,
#   'vwap': 255.235},
#  {'symbol': 'AAPL',
#   'date': '2025-09-25',
#   'open': 253.21,
#   'high': 257.17,
#   'low': 251.71,
#   'close': 256.87,
#   'volume': 55202100,
#   'change': 3.66,
#   'changePercent': 1.45,
#   'vwap': 254.74},
#  {'symbol': 'AAPL',
#   'date': '2025-09-24',
#   'open': 255.22,
#   'high': 255.74,
#   'low': 251.04,
#   'close': 252.31,
#   'volume': 42303710,
#   'change': -2.91,
#   'changePercent': -1.14,
#   'vwap': 253.5775},
#  {'symbol': 'AAPL',
#   'date': '2025-09-23',
#   'open': 255.88,
#   'high': 257.34,
#   'low': 253.58,
#   'close': 254.43,
#   'volume': 60275200,
#   'change': -1.44,
#   'changePercent': -0.56667,
#   'vwap': 255.3075},
#  {'symbol': 'AAPL',
#   'date': '2025-09-22',
#   'open': 248.3,
#   'high': 256.64,
#   'low': 248.12,
#   'close': 256.08,
#   'volume': 105517416,
#   'change': 7.78,
#   'changePercent': 3.13,
#   'vwap': 252.285},
#  {'symbol': 'AAPL',
#   'date': '2025-09-19',
#   'open': 241.23,
#   'high': 246.3,
#   'low': 240.21,
#   'close': 245.5,
#   'volume': 163741314,
#   'change': 4.28,
#   'changePercent': 1.77,
#   'vwap': 243.31},
#  {'symbol': 'AAPL',
#   'date': '2025-09-18',
#   'open': 239.97,
#   'high': 241.2,
#   'low': 236.65,
#   'close': 237.88,
#   'volume': 44249600,
#   'change': -2.09,
#   'changePercent': -0.87094,
#   'vwap': 238.925},
#  {'symbol': 'AAPL',
#   'date': '2025-09-17',
#   'open': 238.97,
#   'high': 240.1,
#   'low': 237.73,
#   'close': 238.99,
#   'volume': 46508017,
#   'change': 0.02,
#   'changePercent': 0.00836925,
#   'vwap': 238.9475},
#  {'symbol': 'AAPL',
#   'date': '2025-09-16',
#   'open': 237.18,
#   'high': 241.22,
#   'low': 236.32,
#   'close': 238.15,
#   'volume': 63421100,
#   'change': 0.975,
#   'changePercent': 0.40897,
#   'vwap': 238.2175},
#  {'symbol': 'AAPL',
#   'date': '2025-09-15',
#   'open': 237,
#   'high': 238.19,
#   'low': 235.03,
#   'close': 236.7,
#   'volume': 42699524,
#   'change': -0.3,
#   'changePercent': -0.12658,
#   'vwap': 236.73},
#  {'symbol': 'AAPL',
#   'date': '2025-09-12',
#   'open': 229.22,
#   'high': 234.51,
#   'low': 229.02,
#   'close': 234.07,
#   'volume': 55824216,
#   'change': 4.85,
#   'changePercent': 2.12,
#   'vwap': 231.705},
#  {'symbol': 'AAPL',
#   'date': '2025-09-11',
#   'open': 226.88,
#   'high': 230.45,
#   'low': 226.65,
#   'close': 230.03,
#   'volume': 50208600,
#   'change': 3.16,
#   'changePercent': 1.39,
#   'vwap': 228.5025},
#  {'symbol': 'AAPL',
#   'date': '2025-09-10',
#   'open': 232.19,
#   'high': 232.42,
#   'low': 225.95,
#   'close': 226.79,
#   'volume': 83440810,
#   'change': -5.4,
#   'changePercent': -2.33,
#   'vwap': 229.3375},
#  {'symbol': 'AAPL',
#   'date': '2025-09-09',
#   'open': 237,
#   'high': 238.78,
#   'low': 233.36,
#   'close': 234.35,
#   'volume': 66313918,
#   'change': -2.65,
#   'changePercent': -1.12,
#   'vwap': 235.8725},
#  {'symbol': 'AAPL',
#   'date': '2025-09-08',
#   'open': 239.3,
#   'high': 240.15,
#   'low': 236.34,
#   'close': 237.88,
#   'volume': 48999500,
#   'change': -1.42,
#   'changePercent': -0.5934,
#   'vwap': 238.4175},
#  {'symbol': 'AAPL',
#   'date': '2025-09-05',
#   'open': 240,
#   'high': 241.32,
#   'low': 238.49,
#   'close': 239.69,
#   'volume': 54870400,
#   'change': -0.305,
#   'changePercent': -0.12917,
#   'vwap': 239.875},
#  {'symbol': 'AAPL',
#   'date': '2025-09-04',
#   'open': 238.45,
#   'high': 239.9,
#   'low': 236.74,
#   'close': 239.78,
#   'volume': 47549429,
#   'change': 1.33,
#   'changePercent': 0.55777,
#   'vwap': 238.7175},
#  {'symbol': 'AAPL',
#   'date': '2025-09-03',
#   'open': 237.21,
#   'high': 238.85,
#   'low': 234.36,
#   'close': 238.47,
#   'volume': 66427835,
#   'change': 1.26,
#   'changePercent': 0.53117,
#   'vwap': 237.2225},
#  {'symbol': 'AAPL',
#   'date': '2025-09-02',
#   'open': 229.25,
#   'high': 230.85,
#   'low': 226.97,
#   'close': 229.72,
#   'volume': 44075638,
#   'change': 0.47,
#   'changePercent': 0.20502,
#   'vwap': 229.1975},
#  {'symbol': 'AAPL',
#   'date': '2025-08-29',
#   'open': 232.51,
#   'high': 233.38,
#   'low': 231.37,
#   'close': 232.14,
#   'volume': 39418437,
#   'change': -0.37,
#   'changePercent': -0.15913,
#   'vwap': 232.35},
#  {'symbol': 'AAPL',
#   'date': '2025-08-28',
#   'open': 230.82,
#   'high': 233.41,
#   'low': 229.34,
#   'close': 232.56,
#   'volume': 38074700,
#   'change': 1.74,
#   'changePercent': 0.75383,
#   'vwap': 231.5325},
#  {'symbol': 'AAPL',
#   'date': '2025-08-27',
#   'open': 228.61,
#   'high': 230.9,
#   'low': 228.26,
#   'close': 230.49,
#   'volume': 31259513,
#   'change': 1.88,
#   'changePercent': 0.82236,
#   'vwap': 229.565},
#  {'symbol': 'AAPL',
#   'date': '2025-08-26',
#   'open': 226.87,
#   'high': 229.49,
#   'low': 224.69,
#   'close': 229.31,
#   'volume': 54575107,
#   'change': 2.44,
#   'changePercent': 1.08,
#   'vwap': 227.59},
#  {'symbol': 'AAPL',
#   'date': '2025-08-25',
#   'open': 226.48,
#   'high': 229.3,
#   'low': 226.23,
#   'close': 227.16,
#   'volume': 30983133,
#   'change': 0.68,
#   'changePercent': 0.30025,
#   'vwap': 227.2925},
#  {'symbol': 'AAPL',
#   'date': '2025-08-22',
#   'open': 226.17,
#   'high': 229.09,
#   'low': 225.41,
#   'close': 227.76,
#   'volume': 42477811,
#   'change': 1.59,
#   'changePercent': 0.70301,
#   'vwap': 227.1075},
#  {'symbol': 'AAPL',
#   'date': '2025-08-21',
#   'open': 226.27,
#   'high': 226.52,
#   'low': 223.78,
#   'close': 224.9,
#   'volume': 30621249,
#   'change': -1.37,
#   'changePercent': -0.60547,
#   'vwap': 225.3675},
#  {'symbol': 'AAPL',
#   'date': '2025-08-20',
#   'open': 229.98,
#   'high': 230.47,
#   'low': 225.77,
#   'close': 226.01,
#   'volume': 42263900,
#   'change': -3.97,
#   'changePercent': -1.73,
#   'vwap': 228.0575},
#  {'symbol': 'AAPL',
#   'date': '2025-08-19',
#   'open': 231.28,
#   'high': 232.87,
#   'low': 229.35,
#   'close': 230.56,
#   'volume': 39402600,
#   'change': -0.715,
#   'changePercent': -0.31131,
#   'vwap': 231.015},
#  {'symbol': 'AAPL',
#   'date': '2025-08-18',
#   'open': 231.7,
#   'high': 233.12,
#   'low': 230.11,
#   'close': 230.89,
#   'volume': 37476200,
#   'change': -0.81,
#   'changePercent': -0.34959,
#   'vwap': 231.455},
#  {'symbol': 'AAPL',
#   'date': '2025-08-15',
#   'open': 234,
#   'high': 234.28,
#   'low': 229.34,
#   'close': 231.59,
#   'volume': 56038700,
#   'change': -2.41,
#   'changePercent': -1.03,
#   'vwap': 232.3025},
#  {'symbol': 'AAPL',
#   'date': '2025-08-14',
#   'open': 234.06,
#   'high': 235.12,
#   'low': 230.85,
#   'close': 232.78,
#   'volume': 51916300,
#   'change': -1.28,
#   'changePercent': -0.54687,
#   'vwap': 233.2025},
#  {'symbol': 'AAPL',
#   'date': '2025-08-13',
#   'open': 231.07,
#   'high': 235,
#   'low': 230.43,
#   'close': 233.33,
#   'volume': 69878546,
#   'change': 2.26,
#   'changePercent': 0.97806,
#   'vwap': 232.4575},
#  {'symbol': 'AAPL',
#   'date': '2025-08-12',
#   'open': 228.01,
#   'high': 230.8,
#   'low': 227.07,
#   'close': 229.65,
#   'volume': 55672301,
#   'change': 1.65,
#   'changePercent': 0.71927,
#   'vwap': 228.8825},
#  {'symbol': 'AAPL',
#   'date': '2025-08-11',
#   'open': 227.92,
#   'high': 229.56,
#   'low': 224.76,
#   'close': 227.18,
#   'volume': 61806132,
#   'change': -0.74,
#   'changePercent': -0.32468,
#   'vwap': 227.355},
#  {'symbol': 'AAPL',
#   'date': '2025-08-08',
#   'open': 220.83,
#   'high': 231,
#   'low': 219.25,
#   'close': 229.35,
#   'volume': 113854000,
#   'change': 8.52,
#   'changePercent': 3.86,
#   'vwap': 225.1075},
#  {'symbol': 'AAPL',
#   'date': '2025-08-07',
#   'open': 218.88,
#   'high': 220.85,
#   'low': 216.58,
#   'close': 220.03,
#   'volume': 90224834,
#   'change': 1.16,
#   'changePercent': 0.5254,
#   'vwap': 219.085},
#  {'symbol': 'AAPL',
#   'date': '2025-08-06',
#   'open': 205.63,
#   'high': 215.38,
#   'low': 205.59,
#   'close': 213.25,
#   'volume': 108483103,
#   'change': 7.62,
#   'changePercent': 3.71,
#   'vwap': 209.9625},
#  {'symbol': 'AAPL',
#   'date': '2025-08-05',
#   'open': 203.4,
#   'high': 205.34,
#   'low': 202.16,
#   'close': 202.92,
#   'volume': 44155100,
#   'change': -0.48,
#   'changePercent': -0.23599,
#   'vwap': 203.455},
#  {'symbol': 'AAPL',
#   'date': '2025-08-04',
#   'open': 204.51,
#   'high': 207.88,
#   'low': 201.68,
#   'close': 203.35,
#   'volume': 75109300,
#   'change': -1.16,
#   'changePercent': -0.56721,
#   'vwap': 204.355},
#  {'symbol': 'AAPL',
#   'date': '2025-08-01',
#   'open': 210.87,
#   'high': 213.58,
#   'low': 201.5,
#   'close': 202.38,
#   'volume': 104434500,
#   'change': -8.49,
#   'changePercent': -4.03,
#   'vwap': 207.0825},
#  {'symbol': 'AAPL',
#   'date': '2025-07-31',
#   'open': 208.49,
#   'high': 209.84,
#   'low': 207.16,
#   'close': 207.57,
#   'volume': 80698431,
#   'change': -0.92,
#   'changePercent': -0.44127,
#   'vwap': 208.265},
#  {'symbol': 'AAPL',
#   'date': '2025-07-30',
#   'open': 211.9,
#   'high': 212.39,
#   'low': 207.72,
#   'close': 209.05,
#   'volume': 45512514,
#   'change': -2.84,
#   'changePercent': -1.34,
#   'vwap': 210.265},
#  {'symbol': 'AAPL',
#   'date': '2025-07-29',
#   'open': 214.18,
#   'high': 214.81,
#   'low': 210.82,
#   'close': 211.27,
#   'volume': 51411723,
#   'change': -2.91,
#   'changePercent': -1.36,
#   'vwap': 212.77},
#  {'symbol': 'AAPL',
#   'date': '2025-07-28',
#   'open': 214.03,
#   'high': 214.85,
#   'low': 213.06,
#   'close': 214.05,
#   'volume': 37858017,
#   'change': 0.02,
#   'changePercent': 0.00934448,
#   'vwap': 213.9975},
#  {'symbol': 'AAPL',
#   'date': '2025-07-25',
#   'open': 214.7,
#   'high': 215.24,
#   'low': 213.4,
#   'close': 213.88,
#   'volume': 40268800,
#   'change': -0.82,
#   'changePercent': -0.38193,
#   'vwap': 214.305},
#  {'symbol': 'AAPL',
#   'date': '2025-07-24',
#   'open': 213.9,
#   'high': 215.69,
#   'low': 213.53,
#   'close': 213.76,
#   'volume': 46022620,
#   'change': -0.14,
#   'changePercent': -0.06545115,
#   'vwap': 214.22},
#  {'symbol': 'AAPL',
#   'date': '2025-07-23',
#   'open': 215,
#   'high': 215.15,
#   'low': 212.41,
#   'close': 214.15,
#   'volume': 46989301,
#   'change': -0.85,
#   'changePercent': -0.39535,
#   'vwap': 214.1775},
#  {'symbol': 'AAPL',
#   'date': '2025-07-22',
#   'open': 213.14,
#   'high': 214.95,
#   'low': 212.23,
#   'close': 214.4,
#   'volume': 46404100,
#   'change': 1.26,
#   'changePercent': 0.59116,
#   'vwap': 213.68},
#  {'symbol': 'AAPL',
#   'date': '2025-07-21',
#   'open': 212.1,
#   'high': 215.78,
#   'low': 211.63,
#   'close': 212.48,
#   'volume': 51377434,
#   'change': 0.38,
#   'changePercent': 0.17916,
#   'vwap': 212.9975},
#  {'symbol': 'AAPL',
#   'date': '2025-07-18',
#   'open': 210.87,
#   'high': 211.79,
#   'low': 209.7,
#   'close': 211.18,
#   'volume': 48974600,
#   'change': 0.31,
#   'changePercent': 0.14701,
#   'vwap': 210.885},
#  {'symbol': 'AAPL',
#   'date': '2025-07-17',
#   'open': 210.57,
#   'high': 211.8,
#   'low': 209.59,
#   'close': 210.02,
#   'volume': 48068141,
#   'change': -0.55,
#   'changePercent': -0.2612,
#   'vwap': 210.495},
#  {'symbol': 'AAPL',
#   'date': '2025-07-16',
#   'open': 210.3,
#   'high': 212.4,
#   'low': 208.64,
#   'close': 210.16,
#   'volume': 47490532,
#   'change': -0.135,
#   'changePercent': -0.06657156,
#   'vwap': 210.375},
#  {'symbol': 'AAPL',
#   'date': '2025-07-15',
#   'open': 209.22,
#   'high': 211.89,
#   'low': 208.92,
#   'close': 209.11,
#   'volume': 42296339,
#   'change': -0.11,
#   'changePercent': -0.05257624,
#   'vwap': 209.785},
#  {'symbol': 'AAPL',
#   'date': '2025-07-14',
#   'open': 209.93,
#   'high': 210.91,
#   'low': 207.54,
#   'close': 208.62,
#   'volume': 38840111,
#   'change': -1.31,
#   'changePercent': -0.62402,
#   'vwap': 209.25},
#  {'symbol': 'AAPL',
#   'date': '2025-07-11',
#   'open': 210.57,
#   'high': 212.13,
#   'low': 209.86,
#   'close': 211.16,
#   'volume': 39765812,
#   'change': 0.595,
#   'changePercent': 0.28019,
#   'vwap': 210.93},
#  {'symbol': 'AAPL',
#   'date': '2025-07-10',
#   'open': 210.51,
#   'high': 213.48,
#   'low': 210.03,
#   'close': 212.41,
#   'volume': 44443635,
#   'change': 1.91,
#   'changePercent': 0.90257,
#   'vwap': 211.6075},
#  {'symbol': 'AAPL',
#   'date': '2025-07-09',
#   'open': 209.53,
#   'high': 211.33,
#   'low': 207.22,
#   'close': 211.14,
#   'volume': 48749400,
#   'change': 1.61,
#   'changePercent': 0.76839,
#   'vwap': 209.805},
#  {'symbol': 'AAPL',
#   'date': '2025-07-08',
#   'open': 210.1,
#   'high': 211.43,
#   'low': 208.45,
#   'close': 210.01,
#   'volume': 42848928,
#   'change': -0.09,
#   'changePercent': -0.04283674,
#   'vwap': 209.9975},
#  {'symbol': 'AAPL',
#   'date': '2025-07-07',
#   'open': 212.68,
#   'high': 216.23,
#   'low': 208.8,
#   'close': 209.95,
#   'volume': 50229000,
#   'change': -2.73,
#   'changePercent': -1.28,
#   'vwap': 211.915},
#  {'symbol': 'AAPL',
#   'date': '2025-07-03',
#   'open': 212.15,
#   'high': 214.65,
#   'low': 211.81,
#   'close': 213.55,
#   'volume': 34955836,
#   'change': 1.41,
#   'changePercent': 0.65991,
#   'vwap': 213.04},
#  {'symbol': 'AAPL',
#   'date': '2025-07-02',
#   'open': 208.91,
#   'high': 213.34,
#   'low': 208.14,
#   'close': 212.44,
#   'volume': 67941811,
#   'change': 3.53,
#   'changePercent': 1.69,
#   'vwap': 210.7075},
#  {'symbol': 'AAPL',
#   'date': '2025-07-01',
#   'open': 206.67,
#   'high': 210.19,
#   'low': 206.14,
#   'close': 207.82,
#   'volume': 78788900,
#   'change': 1.16,
#   'changePercent': 0.55644,
#   'vwap': 207.705},
#  {'symbol': 'AAPL',
#   'date': '2025-06-30',
#   'open': 202.01,
#   'high': 207.39,
#   'low': 199.26,
#   'close': 205.17,
#   'volume': 91912816,
#   'change': 3.16,
#   'changePercent': 1.56,
#   'vwap': 203.4575},
#  {'symbol': 'AAPL',
#   'date': '2025-06-27',
#   'open': 201.89,
#   'high': 203.22,
#   'low': 200,
#   'close': 201.08,
#   'volume': 73188600,
#   'change': -0.81,
#   'changePercent': -0.40121,
#   'vwap': 201.5475},
#  {'symbol': 'AAPL',
#   'date': '2025-06-26',
#   'open': 201.43,
#   'high': 202.64,
#   'low': 199.46,
#   'close': 201,
#   'volume': 50799121,
#   'change': -0.43,
#   'changePercent': -0.21347,
#   'vwap': 201.1325},
#  {'symbol': 'AAPL',
#   'date': '2025-06-25',
#   'open': 201.45,
#   'high': 203.67,
#   'low': 200.62,
#   'close': 201.56,
#   'volume': 39525730,
#   'change': 0.11,
#   'changePercent': 0.05460412,
#   'vwap': 201.825},
#  {'symbol': 'AAPL',
#   'date': '2025-06-24',
#   'open': 202.59,
#   'high': 203.44,
#   'low': 200.2,
#   'close': 200.3,
#   'volume': 54064033,
#   'change': -2.29,
#   'changePercent': -1.13,
#   'vwap': 201.6325},
#  {'symbol': 'AAPL',
#   'date': '2025-06-23',
#   'open': 201.63,
#   'high': 202.3,
#   'low': 198.96,
#   'close': 201.5,
#   'volume': 55814300,
#   'change': -0.125,
#   'changePercent': -0.06447453,
#   'vwap': 201.0975},
#  {'symbol': 'AAPL',
#   'date': '2025-06-20',
#   'open': 198.24,
#   'high': 201.7,
#   'low': 196.86,
#   'close': 201,
#   'volume': 96813542,
#   'change': 2.76,
#   'changePercent': 1.39,
#   'vwap': 199.45},
#  {'symbol': 'AAPL',
#   'date': '2025-06-18',
#   'open': 195.94,
#   'high': 197.57,
#   'low': 195.07,
#   'close': 196.58,
#   'volume': 45394700,
#   'change': 0.64,
#   'changePercent': 0.32663,
#   'vwap': 196.29},
#  {'symbol': 'AAPL',
#   'date': '2025-06-17',
#   'open': 197.2,
#   'high': 198.39,
#   'low': 195.21,
#   'close': 195.64,
#   'volume': 38856200,
#   'change': -1.56,
#   'changePercent': -0.79108,
#   'vwap': 196.61},
#  {'symbol': 'AAPL',
#   'date': '2025-06-16',
#   'open': 197.3,
#   'high': 198.69,
#   'low': 196.56,
#   'close': 198.42,
#   'volume': 43020700,
#   'change': 1.12,
#   'changePercent': 0.56766,
#   'vwap': 197.7425},
#  {'symbol': 'AAPL',
#   'date': '2025-06-13',
#   'open': 199.73,
#   'high': 200.37,
#   'low': 195.7,
#   'close': 196.45,
#   'volume': 51447349,
#   'change': -3.28,
#   'changePercent': -1.64,
#   'vwap': 198.0625},
#  {'symbol': 'AAPL',
#   'date': '2025-06-12',
#   'open': 199.08,
#   'high': 199.68,
#   'low': 197.36,
#   'close': 199.2,
#   'volume': 43904635,
#   'change': 0.12,
#   'changePercent': 0.06027728,
#   'vwap': 198.83},
#  {'symbol': 'AAPL',
#   'date': '2025-06-11',
#   'open': 203.5,
#   'high': 204.5,
#   'low': 198.41,
#   'close': 198.78,
#   'volume': 60989900,
#   'change': -4.72,
#   'changePercent': -2.32,
#   'vwap': 201.2975},
#  {'symbol': 'AAPL',
#   'date': '2025-06-10',
#   'open': 200.6,
#   'high': 204.35,
#   'low': 200.57,
#   'close': 202.67,
#   'volume': 54672608,
#   'change': 2.07,
#   'changePercent': 1.03,
#   'vwap': 202.0475},
#  {'symbol': 'AAPL',
#   'date': '2025-06-09',
#   'open': 204.39,
#   'high': 206,
#   'low': 200.02,
#   'close': 201.45,
#   'volume': 72862600,
#   'change': -2.94,
#   'changePercent': -1.44,
#   'vwap': 202.965},
#  {'symbol': 'AAPL',
#   'date': '2025-06-06',
#   'open': 203,
#   'high': 205.7,
#   'low': 202.05,
#   'close': 203.92,
#   'volume': 46607700,
#   'change': 0.92,
#   'changePercent': 0.4532,
#   'vwap': 203.6675},
#  {'symbol': 'AAPL',
#   'date': '2025-06-05',
#   'open': 203.5,
#   'high': 204.75,
#   'low': 200.15,
#   'close': 200.63,
#   'volume': 55221235,
#   'change': -2.87,
#   'changePercent': -1.41,
#   'vwap': 202.2575},
#  {'symbol': 'AAPL',
#   'date': '2025-06-04',
#   'open': 202.91,
#   'high': 206.24,
#   'low': 202.1,
#   'close': 202.82,
#   'volume': 43604000,
#   'change': -0.09,
#   'changePercent': -0.04435464,
#   'vwap': 203.5175},
#  {'symbol': 'AAPL',
#   'date': '2025-06-03',
#   'open': 201.35,
#   'high': 203.77,
#   'low': 200.96,
#   'close': 203.27,
#   'volume': 46381600,
#   'change': 1.92,
#   'changePercent': 0.95356,
#   'vwap': 202.3375},
#  {'symbol': 'AAPL',
#   'date': '2025-06-02',
#   'open': 200.28,
#   'high': 202.13,
#   'low': 200.12,
#   'close': 201.7,
#   'volume': 35423300,
#   'change': 1.42,
#   'changePercent': 0.70901,
#   'vwap': 201.0575},
#  {'symbol': 'AAPL',
#   'date': '2025-05-30',
#   'open': 199.37,
#   'high': 201.96,
#   'low': 196.78,
#   'close': 200.85,
#   'volume': 70819942,
#   'change': 1.48,
#   'changePercent': 0.74234,
#   'vwap': 199.74},
#  {'symbol': 'AAPL',
#   'date': '2025-05-29',
#   'open': 203.58,
#   'high': 203.81,
#   'low': 198.51,
#   'close': 199.95,
#   'volume': 51477938,
#   'change': -3.62,
#   'changePercent': -1.78,
#   'vwap': 201.4625},
#  {'symbol': 'AAPL',
#   'date': '2025-05-28',
#   'open': 200.59,
#   'high': 202.73,
#   'low': 199.9,
#   'close': 200.42,
#   'volume': 45339700,
#   'change': -0.17,
#   'changePercent': -0.08474999,
#   'vwap': 200.91},
#  {'symbol': 'AAPL',
#   'date': '2025-05-27',
#   'open': 198.3,
#   'high': 200.74,
#   'low': 197.43,
#   'close': 200.21,
#   'volume': 56288500,
#   'change': 1.91,
#   'changePercent': 0.96319,
#   'vwap': 199.17},
#  {'symbol': 'AAPL',
#   'date': '2025-05-23',
#   'open': 193.67,
#   'high': 197.7,
#   'low': 193.46,
#   'close': 195.27,
#   'volume': 78432918,
#   'change': 1.61,
#   'changePercent': 0.82615,
#   'vwap': 195.025},
#  {'symbol': 'AAPL',
#   'date': '2025-05-22',
#   'open': 200.71,
#   'high': 202.75,
#   'low': 199.7,
#   'close': 201.36,
#   'volume': 46742407,
#   'change': 0.65,
#   'changePercent': 0.32385,
#   'vwap': 201.13},
#  {'symbol': 'AAPL',
#   'date': '2025-05-21',
#   'open': 205.17,
#   'high': 207.04,
#   'low': 200.71,
#   'close': 202.09,
#   'volume': 59211800,
#   'change': -3.08,
#   'changePercent': -1.5,
#   'vwap': 203.7525},
#  {'symbol': 'AAPL',
#   'date': '2025-05-20',
#   'open': 207.67,
#   'high': 208.47,
#   'low': 205.03,
#   'close': 206.86,
#   'volume': 42496635,
#   'change': -0.81,
#   'changePercent': -0.39004,
#   'vwap': 207.0075},
#  {'symbol': 'AAPL',
#   'date': '2025-05-19',
#   'open': 207.91,
#   'high': 209.48,
#   'low': 204.26,
#   'close': 208.78,
#   'volume': 46140527,
#   'change': 0.87,
#   'changePercent': 0.41845,
#   'vwap': 207.6075},
#  {'symbol': 'AAPL',
#   'date': '2025-05-16',
#   'open': 212.36,
#   'high': 212.57,
#   'low': 209.77,
#   'close': 211.26,
#   'volume': 54737900,
#   'change': -1.1,
#   'changePercent': -0.51799,
#   'vwap': 211.49},
#  {'symbol': 'AAPL',
#   'date': '2025-05-15',
#   'open': 210.95,
#   'high': 212.96,
#   'low': 209.54,
#   'close': 211.45,
#   'volume': 45029500,
#   'change': 0.5,
#   'changePercent': 0.23702,
#   'vwap': 211.225},
#  {'symbol': 'AAPL',
#   'date': '2025-05-14',
#   'open': 212.43,
#   'high': 213.94,
#   'low': 210.58,
#   'close': 212.33,
#   'volume': 49325825,
#   'change': -0.1,
#   'changePercent': -0.04707433,
#   'vwap': 212.32},
#  {'symbol': 'AAPL',
#   'date': '2025-05-13',
#   'open': 210.43,
#   'high': 213.4,
#   'low': 209,
#   'close': 212.93,
#   'volume': 51909332,
#   'change': 2.5,
#   'changePercent': 1.19,
#   'vwap': 211.44},
#  {'symbol': 'AAPL',
#   'date': '2025-05-12',
#   'open': 210.97,
#   'high': 211.27,
#   'low': 206.75,
#   'close': 210.79,
#   'volume': 63775814,
#   'change': -0.18,
#   'changePercent': -0.08532019,
#   'vwap': 209.945},
#  {'symbol': 'AAPL',
#   'date': '2025-05-09',
#   'open': 199,
#   'high': 200.54,
#   'low': 197.54,
#   'close': 198.53,
#   'volume': 36453923,
#   'change': -0.47,
#   'changePercent': -0.23618,
#   'vwap': 198.9025},
#  {'symbol': 'AAPL',
#   'date': '2025-05-08',
#   'open': 197.72,
#   'high': 200.05,
#   'low': 194.68,
#   'close': 197.49,
#   'volume': 50478900,
#   'change': -0.23,
#   'changePercent': -0.11633,
#   'vwap': 197.485},
#  {'symbol': 'AAPL',
#   'date': '2025-05-07',
#   'open': 199.17,
#   'high': 199.44,
#   'low': 193.25,
#   'close': 196.25,
#   'volume': 68616943,
#   'change': -2.92,
#   'changePercent': -1.47,
#   'vwap': 197.0275},
#  {'symbol': 'AAPL',
#   'date': '2025-05-06',
#   'open': 198.21,
#   'high': 200.65,
#   'low': 197.02,
#   'close': 198.51,
#   'volume': 51216500,
#   'change': 0.3,
#   'changePercent': 0.15135,
#   'vwap': 198.5975},
#  {'symbol': 'AAPL',
#   'date': '2025-05-05',
#   'open': 203.1,
#   'high': 204.1,
#   'low': 198.21,
#   'close': 198.89,
#   'volume': 69018500,
#   'change': -4.21,
#   'changePercent': -2.07,
#   'vwap': 201.075},
#  {'symbol': 'AAPL',
#   'date': '2025-05-02',
#   'open': 206.09,
#   'high': 206.99,
#   'low': 202.16,
#   'close': 205.35,
#   'volume': 101010621,
#   'change': -0.74,
#   'changePercent': -0.35907,
#   'vwap': 205.1475},
#  {'symbol': 'AAPL',
#   'date': '2025-05-01',
#   'open': 209.08,
#   'high': 214.56,
#   'low': 208.9,
#   'close': 213.32,
#   'volume': 57365700,
#   'change': 4.24,
#   'changePercent': 2.03,
#   'vwap': 211.465},
#  {'symbol': 'AAPL',
#   'date': '2025-04-30',
#   'open': 209.3,
#   'high': 213.58,
#   'low': 206.67,
#   'close': 212.5,
#   'volume': 52286500,
#   'change': 3.2,
#   'changePercent': 1.53,
#   'vwap': 210.5125},
#  {'symbol': 'AAPL',
#   'date': '2025-04-29',
#   'open': 208.69,
#   'high': 212.24,
#   'low': 208.37,
#   'close': 211.21,
#   'volume': 36827633,
#   'change': 2.52,
#   'changePercent': 1.21,
#   'vwap': 210.1275},
#  {'symbol': 'AAPL',
#   'date': '2025-04-28',
#   'open': 210,
#   'high': 211.5,
#   'low': 207.46,
#   'close': 210.14,
#   'volume': 38743100,
#   'change': 0.14,
#   'changePercent': 0.06666667,
#   'vwap': 209.775},
#  {'symbol': 'AAPL',
#   'date': '2025-04-25',
#   'open': 206.37,
#   'high': 209.75,
#   'low': 206.2,
#   'close': 209.28,
#   'volume': 38222300,
#   'change': 2.91,
#   'changePercent': 1.41,
#   'vwap': 207.9},
#  {'symbol': 'AAPL',
#   'date': '2025-04-24',
#   'open': 204.89,
#   'high': 208.83,
#   'low': 202.94,
#   'close': 208.37,
#   'volume': 47311000,
#   'change': 3.48,
#   'changePercent': 1.7,
#   'vwap': 206.2575},
#  {'symbol': 'AAPL',
#   'date': '2025-04-23',
#   'open': 206,
#   'high': 208,
#   'low': 202.8,
#   'close': 204.6,
#   'volume': 52929200,
#   'change': -1.4,
#   'changePercent': -0.67961,
#   'vwap': 205.35},
#  {'symbol': 'AAPL',
#   'date': '2025-04-22',
#   'open': 196.12,
#   'high': 201.59,
#   'low': 195.97,
#   'close': 199.74,
#   'volume': 52976400,
#   'change': 3.62,
#   'changePercent': 1.85,
#   'vwap': 198.355},
#  {'symbol': 'AAPL',
#   'date': '2025-04-21',
#   'open': 193.27,
#   'high': 193.8,
#   'low': 189.81,
#   'close': 193.16,
#   'volume': 46742537,
#   'change': -0.105,
#   'changePercent': -0.0569152,
#   'vwap': 192.51},
#  {'symbol': 'AAPL',
#   'date': '2025-04-17',
#   'open': 197.2,
#   'high': 198.83,
#   'low': 194.42,
#   'close': 196.98,
#   'volume': 52164700,
#   'change': -0.22,
#   'changePercent': -0.11156,
#   'vwap': 196.8575},
#  {'symbol': 'AAPL',
#   'date': '2025-04-16',
#   'open': 198.36,
#   'high': 200.7,
#   'low': 192.37,
#   'close': 194.27,
#   'volume': 59732423,
#   'change': -4.09,
#   'changePercent': -2.06,
#   'vwap': 196.425},
#  {'symbol': 'AAPL',
#   'date': '2025-04-15',
#   'open': 201.86,
#   'high': 203.51,
#   'low': 199.8,
#   'close': 202.14,
#   'volume': 51343900,
#   'change': 0.285,
#   'changePercent': 0.13871,
#   'vwap': 201.8275},
#  {'symbol': 'AAPL',
#   'date': '2025-04-14',
#   'open': 211.44,
#   'high': 212.94,
#   'low': 201.16,
#   'close': 202.52,
#   'volume': 101352911,
#   'change': -8.92,
#   'changePercent': -4.22,
#   'vwap': 207.015},
#  {'symbol': 'AAPL',
#   'date': '2025-04-11',
#   'open': 186.1,
#   'high': 199.54,
#   'low': 186.06,
#   'close': 198.15,
#   'volume': 87435915,
#   'change': 12.05,
#   'changePercent': 6.48,
#   'vwap': 192.4625},
#  {'symbol': 'AAPL',
#   'date': '2025-04-10',
#   'open': 189.07,
#   'high': 194.78,
#   'low': 183,
#   'close': 190.42,
#   'volume': 121880000,
#   'change': 1.35,
#   'changePercent': 0.71402,
#   'vwap': 189.3175},
#  {'symbol': 'AAPL',
#   'date': '2025-04-09',
#   'open': 171.95,
#   'high': 200.61,
#   'low': 171.89,
#   'close': 198.85,
#   'volume': 184395900,
#   'change': 26.9,
#   'changePercent': 15.64,
#   'vwap': 185.825},
#  {'symbol': 'AAPL',
#   'date': '2025-04-08',
#   'open': 186.7,
#   'high': 190.34,
#   'low': 169.21,
#   'close': 172.42,
#   'volume': 120859500,
#   'change': -14.28,
#   'changePercent': -7.65,
#   'vwap': 179.6675},
#  {'symbol': 'AAPL',
#   'date': '2025-04-07',
#   'open': 177.2,
#   'high': 194.15,
#   'low': 174.62,
#   'close': 181.46,
#   'volume': 160466300,
#   'change': 4.26,
#   'changePercent': 2.4,
#   'vwap': 181.8575},
#  {'symbol': 'AAPL',
#   'date': '2025-04-04',
#   'open': 193.89,
#   'high': 199.88,
#   'low': 187.34,
#   'close': 188.38,
#   'volume': 125910913,
#   'change': -5.51,
#   'changePercent': -2.84,
#   'vwap': 192.3725},
#  {'symbol': 'AAPL',
#   'date': '2025-04-03',
#   'open': 205.54,
#   'high': 207.49,
#   'low': 201.25,
#   'close': 203.19,
#   'volume': 103419006,
#   'change': -2.35,
#   'changePercent': -1.14,
#   'vwap': 204.3675},
#  {'symbol': 'AAPL',
#   'date': '2025-04-02',
#   'open': 221.32,
#   'high': 225.19,
#   'low': 221.02,
#   'close': 223.89,
#   'volume': 35905904,
#   'change': 2.57,
#   'changePercent': 1.16,
#   'vwap': 222.855},
#  {'symbol': 'AAPL',
#   'date': '2025-04-01',
#   'open': 219.81,
#   'high': 223.68,
#   'low': 218.9,
#   'close': 223.19,
#   'volume': 36412740,
#   'change': 3.38,
#   'changePercent': 1.54,
#   'vwap': 221.395},
#  {'symbol': 'AAPL',
#   'date': '2025-03-31',
#   'open': 217.01,
#   'high': 225.62,
#   'low': 216.23,
#   'close': 222.13,
#   'volume': 65299321,
#   'change': 5.13,
#   'changePercent': 2.36,
#   'vwap': 220.2475},
#  {'symbol': 'AAPL',
#   'date': '2025-03-28',
#   'open': 221.67,
#   'high': 223.81,
#   'low': 217.68,
#   'close': 217.9,
#   'volume': 39818617,
#   'change': -3.77,
#   'changePercent': -1.7,
#   'vwap': 220.265},
#  {'symbol': 'AAPL',
#   'date': '2025-03-27',
#   'open': 221.39,
#   'high': 224.99,
#   'low': 220.56,
#   'close': 223.85,
#   'volume': 37094800,
#   'change': 2.46,
#   'changePercent': 1.11,
#   'vwap': 222.6975},
#  {'symbol': 'AAPL',
#   'date': '2025-03-26',
#   'open': 223.51,
#   'high': 225.02,
#   'low': 220.47,
#   'close': 221.53,
#   'volume': 34532656,
#   'change': -1.98,
#   'changePercent': -0.88587,
#   'vwap': 222.6325},
#  {'symbol': 'AAPL',
#   'date': '2025-03-25',
#   'open': 220.77,
#   'high': 224.1,
#   'low': 220.08,
#   'close': 223.75,
#   'volume': 34493600,
#   'change': 2.98,
#   'changePercent': 1.35,
#   'vwap': 222.175},
#  {'symbol': 'AAPL',
#   'date': '2025-03-24',
#   'open': 221,
#   'high': 221.48,
#   'low': 218.58,
#   'close': 220.73,
#   'volume': 44299500,
#   'change': -0.27,
#   'changePercent': -0.12217,
#   'vwap': 220.4475},
#  {'symbol': 'AAPL',
#   'date': '2025-03-21',
#   'open': 211.56,
#   'high': 218.84,
#   'low': 211.28,
#   'close': 218.27,
#   'volume': 94127800,
#   'change': 6.71,
#   'changePercent': 3.17,
#   'vwap': 214.9875},
#  {'symbol': 'AAPL',
#   'date': '2025-03-20',
#   'open': 213.99,
#   'high': 217.49,
#   'low': 212.22,
#   'close': 214.1,
#   'volume': 48862947,
#   'change': 0.11,
#   'changePercent': 0.05140427,
#   'vwap': 214.45},
#  {'symbol': 'AAPL',
#   'date': '2025-03-19',
#   'open': 214.22,
#   'high': 218.76,
#   'low': 213.75,
#   'close': 215.24,
#   'volume': 54385400,
#   'change': 1.02,
#   'changePercent': 0.47615,
#   'vwap': 215.4925},
#  {'symbol': 'AAPL',
#   'date': '2025-03-18',
#   'open': 214.16,
#   'high': 215.15,
#   'low': 211.49,
#   'close': 212.69,
#   'volume': 42432426,
#   'change': -1.47,
#   'changePercent': -0.6864,
#   'vwap': 213.3725},
#  {'symbol': 'AAPL',
#   'date': '2025-03-17',
#   'open': 213.31,
#   'high': 215.22,
#   'low': 209.97,
#   'close': 214,
#   'volume': 48073426,
#   'change': 0.69,
#   'changePercent': 0.32347,
#   'vwap': 213.125},
#  {'symbol': 'AAPL',
#   'date': '2025-03-14',
#   'open': 211.25,
#   'high': 213.95,
#   'low': 209.58,
#   'close': 213.49,
#   'volume': 60107600,
#   'change': 2.24,
#   'changePercent': 1.06,
#   'vwap': 212.0675},
#  {'symbol': 'AAPL',
#   'date': '2025-03-13',
#   'open': 215.95,
#   'high': 216.84,
#   'low': 208.42,
#   'close': 209.68,
#   'volume': 61368330,
#   'change': -6.27,
#   'changePercent': -2.9,
#   'vwap': 212.7225},
#  {'symbol': 'AAPL',
#   'date': '2025-03-12',
#   'open': 220.14,
#   'high': 221.75,
#   'low': 214.91,
#   'close': 216.98,
#   'volume': 62547500,
#   'change': -3.16,
#   'changePercent': -1.44,
#   'vwap': 218.445},
#  {'symbol': 'AAPL',
#   'date': '2025-03-11',
#   'open': 223.81,
#   'high': 225.84,
#   'low': 217.45,
#   'close': 220.84,
#   'volume': 76137410,
#   'change': -2.97,
#   'changePercent': -1.33,
#   'vwap': 221.985},
#  {'symbol': 'AAPL',
#   'date': '2025-03-10',
#   'open': 235.54,
#   'high': 236.16,
#   'low': 224.22,
#   'close': 227.48,
#   'volume': 72071200,
#   'change': -8.06,
#   'changePercent': -3.42,
#   'vwap': 230.85},
#  {'symbol': 'AAPL',
#   'date': '2025-03-07',
#   'open': 235.11,
#   'high': 241.37,
#   'low': 234.76,
#   'close': 239.07,
#   'volume': 46273600,
#   'change': 3.97,
#   'changePercent': 1.68,
#   'vwap': 237.5775},
#  {'symbol': 'AAPL',
#   'date': '2025-03-06',
#   'open': 234.44,
#   'high': 237.86,
#   'low': 233.16,
#   'close': 235.33,
#   'volume': 45170419,
#   'change': 0.895,
#   'changePercent': 0.37963,
#   'vwap': 235.1975},
#  {'symbol': 'AAPL',
#   'date': '2025-03-05',
#   'open': 235.42,
#   'high': 236.55,
#   'low': 229.23,
#   'close': 235.74,
#   'volume': 47227643,
#   'change': 0.32,
#   'changePercent': 0.13593,
#   'vwap': 234.235},
#  {'symbol': 'AAPL',
#   'date': '2025-03-04',
#   'open': 237.71,
#   'high': 240.07,
#   'low': 234.68,
#   'close': 235.93,
#   'volume': 53798100,
#   'change': -1.78,
#   'changePercent': -0.74881,
#   'vwap': 237.0975},
#  {'symbol': 'AAPL',
#   'date': '2025-03-03',
#   'open': 241.79,
#   'high': 244.03,
#   'low': 236.11,
#   'close': 238.03,
#   'volume': 47184000,
#   'change': -3.76,
#   'changePercent': -1.56,
#   'vwap': 239.99},
#  {'symbol': 'AAPL',
#   'date': '2025-02-28',
#   'open': 236.95,
#   'high': 242.09,
#   'low': 230.2,
#   'close': 241.84,
#   'volume': 56833400,
#   'change': 4.89,
#   'changePercent': 2.06,
#   'vwap': 237.77},
#  {'symbol': 'AAPL',
#   'date': '2025-02-27',
#   'open': 239.41,
#   'high': 242.46,
#   'low': 237.06,
#   'close': 237.3,
#   'volume': 41153639,
#   'change': -2.11,
#   'changePercent': -0.88133,
#   'vwap': 239.0575},
#  {'symbol': 'AAPL',
#   'date': '2025-02-26',
#   'open': 244.33,
#   'high': 244.98,
#   'low': 239.13,
#   'close': 240.36,
#   'volume': 44433600,
#   'change': -3.97,
#   'changePercent': -1.62,
#   'vwap': 242.2},
#  {'symbol': 'AAPL',
#   'date': '2025-02-25',
#   'open': 248,
#   'high': 250,
#   'low': 244.91,
#   'close': 247.04,
#   'volume': 48013300,
#   'change': -0.96,
#   'changePercent': -0.3871,
#   'vwap': 247.4875},
#  {'symbol': 'AAPL',
#   'date': '2025-02-24',
#   'open': 244.93,
#   'high': 248.86,
#   'low': 244.42,
#   'close': 247.1,
#   'volume': 51326400,
#   'change': 2.17,
#   'changePercent': 0.88597,
#   'vwap': 246.3275},
#  {'symbol': 'AAPL',
#   'date': '2025-02-21',
#   'open': 245.95,
#   'high': 248.69,
#   'low': 245.22,
#   'close': 245.55,
#   'volume': 53197431,
#   'change': -0.4,
#   'changePercent': -0.16263,
#   'vwap': 246.3525},
#  {'symbol': 'AAPL',
#   'date': '2025-02-20',
#   'open': 244.94,
#   'high': 246.78,
#   'low': 244.29,
#   'close': 245.83,
#   'volume': 32316907,
#   'change': 0.89,
#   'changePercent': 0.36335,
#   'vwap': 245.46},
#  {'symbol': 'AAPL',
#   'date': '2025-02-19',
#   'open': 244.66,
#   'high': 246.01,
#   'low': 243.16,
#   'close': 244.87,
#   'volume': 32204215,
#   'change': 0.21,
#   'changePercent': 0.0858334,
#   'vwap': 244.675},
#  {'symbol': 'AAPL',
#   'date': '2025-02-18',
#   'open': 244.15,
#   'high': 245.18,
#   'low': 241.84,
#   'close': 244.47,
#   'volume': 48822500,
#   'change': 0.32,
#   'changePercent': 0.13107,
#   'vwap': 243.91},
#  {'symbol': 'AAPL',
#   'date': '2025-02-14',
#   'open': 241.25,
#   'high': 245.55,
#   'low': 240.99,
#   'close': 244.6,
#   'volume': 40896227,
#   'change': 3.35,
#   'changePercent': 1.39,
#   'vwap': 243.0975},
#  {'symbol': 'AAPL',
#   'date': '2025-02-13',
#   'open': 236.91,
#   'high': 242.34,
#   'low': 235.57,
#   'close': 241.53,
#   'volume': 53614100,
#   'change': 4.62,
#   'changePercent': 1.95,
#   'vwap': 239.0875},
#  {'symbol': 'AAPL',
#   'date': '2025-02-12',
#   'open': 231.2,
#   'high': 236.96,
#   'low': 230.68,
#   'close': 236.87,
#   'volume': 45243300,
#   'change': 5.67,
#   'changePercent': 2.45,
#   'vwap': 233.9275},
#  {'symbol': 'AAPL',
#   'date': '2025-02-11',
#   'open': 228.2,
#   'high': 235.23,
#   'low': 228.13,
#   'close': 232.62,
#   'volume': 53718400,
#   'change': 4.42,
#   'changePercent': 1.94,
#   'vwap': 231.045},
#  {'symbol': 'AAPL',
#   'date': '2025-02-10',
#   'open': 229.57,
#   'high': 230.59,
#   'low': 227.2,
#   'close': 227.65,
#   'volume': 33115645,
#   'change': -1.92,
#   'changePercent': -0.83635,
#   'vwap': 228.7525},
#  {'symbol': 'AAPL',
#   'date': '2025-02-07',
#   'open': 232.6,
#   'high': 234,
#   'low': 227.26,
#   'close': 227.63,
#   'volume': 39707224,
#   'change': -4.97,
#   'changePercent': -2.14,
#   'vwap': 230.3725},
#  {'symbol': 'AAPL',
#   'date': '2025-02-06',
#   'open': 231.29,
#   'high': 233.8,
#   'low': 230.43,
#   'close': 233.22,
#   'volume': 29925349,
#   'change': 1.94,
#   'changePercent': 0.83445,
#   'vwap': 232.185},
#  {'symbol': 'AAPL',
#   'date': '2025-02-05',
#   'open': 228.53,
#   'high': 232.67,
#   'low': 228.27,
#   'close': 232.47,
#   'volume': 39664989,
#   'change': 3.94,
#   'changePercent': 1.72,
#   'vwap': 230.485},
#  {'symbol': 'AAPL',
#   'date': '2025-02-04',
#   'open': 227.25,
#   'high': 233.13,
#   'low': 226.65,
#   'close': 232.8,
#   'volume': 45067301,
#   'change': 5.55,
#   'changePercent': 2.44,
#   'vwap': 229.9575},
#  {'symbol': 'AAPL',
#   'date': '2025-02-03',
#   'open': 229.99,
#   'high': 231.83,
#   'low': 225.7,
#   'close': 228.01,
#   'volume': 73063301,
#   'change': -1.98,
#   'changePercent': -0.86091,
#   'vwap': 228.8825},
#  {'symbol': 'AAPL',
#   'date': '2025-01-31',
#   'open': 247.19,
#   'high': 247.19,
#   'low': 233.44,
#   'close': 236,
#   'volume': 101075128,
#   'change': -11.19,
#   'changePercent': -4.53,
#   'vwap': 240.955},
#  {'symbol': 'AAPL',
#   'date': '2025-01-30',
#   'open': 238.67,
#   'high': 240.79,
#   'low': 237.21,
#   'close': 237.59,
#   'volume': 55658300,
#   'change': -1.07,
#   'changePercent': -0.45251,
#   'vwap': 238.565},
#  {'symbol': 'AAPL',
#   'date': '2025-01-29',
#   'open': 234.12,
#   'high': 239.86,
#   'low': 234.01,
#   'close': 239.36,
#   'volume': 45486100,
#   'change': 5.24,
#   'changePercent': 2.24,
#   'vwap': 236.8375},
#  {'symbol': 'AAPL',
#   'date': '2025-01-28',
#   'open': 230.85,
#   'high': 240.19,
#   'low': 230.81,
#   'close': 238.26,
#   'volume': 75707600,
#   'change': 7.41,
#   'changePercent': 3.21,
#   'vwap': 235.0275},
#  {'symbol': 'AAPL',
#   'date': '2025-01-27',
#   'open': 224.02,
#   'high': 232.15,
#   'low': 223.98,
#   'close': 229.86,
#   'volume': 94863418,
#   'change': 5.84,
#   'changePercent': 2.61,
#   'vwap': 227.5025},
#  {'symbol': 'AAPL',
#   'date': '2025-01-24',
#   'open': 224.78,
#   'high': 225.63,
#   'low': 221.41,
#   'close': 222.78,
#   'volume': 54697907,
#   'change': -2,
#   'changePercent': -0.88976,
#   'vwap': 223.65},
#  {'symbol': 'AAPL',
#   'date': '2025-01-23',
#   'open': 224.74,
#   'high': 227.03,
#   'low': 222.3,
#   'close': 223.66,
#   'volume': 60234800,
#   'change': -1.08,
#   'changePercent': -0.48056,
#   'vwap': 224.4325},
#  {'symbol': 'AAPL',
#   'date': '2025-01-22',
#   'open': 219.79,
#   'high': 224.12,
#   'low': 219.79,
#   'close': 223.83,
#   'volume': 64126500,
#   'change': 4.04,
#   'changePercent': 1.84,
#   'vwap': 221.8825},
#  {'symbol': 'AAPL',
#   'date': '2025-01-21',
#   'open': 224,
#   'high': 224.42,
#   'low': 219.38,
#   'close': 222.64,
#   'volume': 98070429,
#   'change': -1.36,
#   'changePercent': -0.60714,
#   'vwap': 222.61},
#  {'symbol': 'AAPL',
#   'date': '2025-01-17',
#   'open': 232.12,
#   'high': 232.29,
#   'low': 228.48,
#   'close': 229.98,
#   'volume': 68488301,
#   'change': -2.14,
#   'changePercent': -0.92194,
#   'vwap': 230.7175},
#  {'symbol': 'AAPL',
#   'date': '2025-01-16',
#   'open': 237.35,
#   'high': 238.01,
#   'low': 228.03,
#   'close': 228.26,
#   'volume': 71759100,
#   'change': -9.09,
#   'changePercent': -3.83,
#   'vwap': 232.9125},
#  {'symbol': 'AAPL',
#   'date': '2025-01-15',
#   'open': 234.64,
#   'high': 238.96,
#   'low': 234.43,
#   'close': 237.87,
#   'volume': 39832000,
#   'change': 3.24,
#   'changePercent': 1.38,
#   'vwap': 236.475},
#  {'symbol': 'AAPL',
#   'date': '2025-01-14',
#   'open': 234.75,
#   'high': 236.12,
#   'low': 232.47,
#   'close': 233.28,
#   'volume': 39435300,
#   'change': -1.47,
#   'changePercent': -0.6262,
#   'vwap': 234.155},
#  {'symbol': 'AAPL',
#   'date': '2025-01-13',
#   'open': 233.53,
#   'high': 234.67,
#   'low': 229.72,
#   'close': 234.4,
#   'volume': 49630725,
#   'change': 0.87,
#   'changePercent': 0.37254,
#   'vwap': 233.08},
#  {'symbol': 'AAPL',
#   'date': '2025-01-10',
#   'open': 240.01,
#   'high': 240.16,
#   'low': 233,
#   'close': 236.85,
#   'volume': 61710900,
#   'change': -3.16,
#   'changePercent': -1.32,
#   'vwap': 237.505},
#  {'symbol': 'AAPL',
#   'date': '2025-01-08',
#   'open': 241.92,
#   'high': 243.71,
#   'low': 240.05,
#   'close': 242.7,
#   'volume': 37628940,
#   'change': 0.78,
#   'changePercent': 0.32242,
#   'vwap': 242.095},
#  {'symbol': 'AAPL',
#   'date': '2025-01-07',
#   'open': 242.98,
#   'high': 245.55,
#   'low': 241.35,
#   'close': 242.21,
#   'volume': 40856000,
#   'change': -0.77,
#   'changePercent': -0.3169,
#   'vwap': 243.0225},
#  {'symbol': 'AAPL',
#   'date': '2025-01-06',
#   'open': 244.31,
#   'high': 247.33,
#   'low': 243.2,
#   'close': 245,
#   'volume': 45045600,
#   'change': 0.69,
#   'changePercent': 0.28243,
#   'vwap': 244.96},
#  {'symbol': 'AAPL',
#   'date': '2025-01-03',
#   'open': 243.36,
#   'high': 244.18,
#   'low': 241.89,
#   'close': 243.36,
#   'volume': 40244114,
#   'change': 0,
#   'changePercent': 0,
#   'vwap': 243.1975},
#  {'symbol': 'AAPL',
#   'date': '2025-01-02',
#   'open': 248.93,
#   'high': 249.1,
#   'low': 241.82,
#   'close': 243.85,
#   'volume': 55740731,
#   'change': -5.08,
#   'changePercent': -2.04,
#   'vwap': 245.925},
#  {'symbol': 'AAPL',
#   'date': '2024-12-31',
#   'open': 252.44,
#   'high': 253.28,
#   'low': 249.43,
#   'close': 250.42,
#   'volume': 39480718,
#   'change': -2.02,
#   'changePercent': -0.80019,
#   'vwap': 251.3925},
#  {'symbol': 'AAPL',
#   'date': '2024-12-30',
#   'open': 252.23,
#   'high': 253.5,
#   'low': 250.75,
#   'close': 252.2,
#   'volume': 35557542,
#   'change': -0.03,
#   'changePercent': -0.01189391,
#   'vwap': 252.17},
#  {'symbol': 'AAPL',
#   'date': '2024-12-27',
#   'open': 257.83,
#   'high': 258.7,
#   'low': 253.06,
#   'close': 255.59,
#   'volume': 42355321,
#   'change': -2.24,
#   'changePercent': -0.86879,
#   'vwap': 256.295},
#  {'symbol': 'AAPL',
#   'date': '2024-12-26',
#   'open': 258.19,
#   'high': 260.1,
#   'low': 257.63,
#   'close': 259.02,
#   'volume': 27262983,
#   'change': 0.83,
#   'changePercent': 0.32147,
#   'vwap': 258.735},
#  {'symbol': 'AAPL',
#   'date': '2024-12-24',
#   'open': 255.49,
#   'high': 258.21,
#   'low': 255.29,
#   'close': 258.2,
#   'volume': 23234705,
#   'change': 2.71,
#   'changePercent': 1.06,
#   'vwap': 256.7975},
#  {'symbol': 'AAPL',
#   'date': '2024-12-23',
#   'open': 254.77,
#   'high': 255.65,
#   'low': 253.45,
#   'close': 255.27,
#   'volume': 40858800,
#   'change': 0.5,
#   'changePercent': 0.19626,
#   'vwap': 254.785},
#  {'symbol': 'AAPL',
#   'date': '2024-12-20',
#   'open': 248.04,
#   'high': 255,
#   'low': 245.69,
#   'close': 254.49,
#   'volume': 147495300,
#   'change': 6.45,
#   'changePercent': 2.6,
#   'vwap': 250.805},
#  {'symbol': 'AAPL',
#   'date': '2024-12-19',
#   'open': 247.5,
#   'high': 252,
#   'low': 247.09,
#   'close': 249.79,
#   'volume': 60882300,
#   'change': 2.29,
#   'changePercent': 0.92525,
#   'vwap': 249.095},
#  {'symbol': 'AAPL',
#   'date': '2024-12-18',
#   'open': 252.16,
#   'high': 254.28,
#   'low': 247.74,
#   'close': 248.05,
#   'volume': 56774101,
#   'change': -4.11,
#   'changePercent': -1.63,
#   'vwap': 250.5575},
#  {'symbol': 'AAPL',
#   'date': '2024-12-17',
#   'open': 250.08,
#   'high': 253.83,
#   'low': 249.78,
#   'close': 253.48,
#   'volume': 51356400,
#   'change': 3.4,
#   'changePercent': 1.36,
#   'vwap': 251.7925},
#  {'symbol': 'AAPL',
#   'date': '2024-12-16',
#   'open': 247.99,
#   'high': 251.38,
#   'low': 247.65,
#   'close': 251.04,
#   'volume': 51694800,
#   'change': 3.05,
#   'changePercent': 1.23,
#   'vwap': 249.515},
#  {'symbol': 'AAPL',
#   'date': '2024-12-13',
#   'open': 247.82,
#   'high': 249.29,
#   'low': 246.24,
#   'close': 248.13,
#   'volume': 33155300,
#   'change': 0.315,
#   'changePercent': 0.12509,
#   'vwap': 247.87},
#  {'symbol': 'AAPL',
#   'date': '2024-12-12',
#   'open': 246.89,
#   'high': 248.74,
#   'low': 245.68,
#   'close': 247.96,
#   'volume': 32777532,
#   'change': 1.07,
#   'changePercent': 0.43339,
#   'vwap': 247.3175},
#  {'symbol': 'AAPL',
#   'date': '2024-12-11',
#   'open': 247.96,
#   'high': 250.8,
#   'low': 246.26,
#   'close': 246.49,
#   'volume': 45205814,
#   'change': -1.47,
#   'changePercent': -0.59284,
#   'vwap': 247.8775},
#  {'symbol': 'AAPL',
#   'date': '2024-12-10',
#   'open': 246.89,
#   'high': 248.21,
#   'low': 245.34,
#   'close': 247.77,
#   'volume': 36914806,
#   'change': 0.88,
#   'changePercent': 0.35643,
#   'vwap': 247.0525},
#  {'symbol': 'AAPL',
#   'date': '2024-12-09',
#   'open': 241.83,
#   'high': 247.24,
#   'low': 241.75,
#   'close': 246.75,
#   'volume': 44649232,
#   'change': 4.92,
#   'changePercent': 2.03,
#   'vwap': 244.3925},
#  {'symbol': 'AAPL',
#   'date': '2024-12-06',
#   'open': 242.91,
#   'high': 244.63,
#   'low': 242.08,
#   'close': 242.84,
#   'volume': 36870619,
#   'change': -0.065,
#   'changePercent': -0.02881726,
#   'vwap': 243.115},
#  {'symbol': 'AAPL',
#   'date': '2024-12-05',
#   'open': 243.99,
#   'high': 244.54,
#   'low': 242.13,
#   'close': 243.04,
#   'volume': 40033900,
#   'change': -0.95,
#   'changePercent': -0.38936,
#   'vwap': 243.425},
#  {'symbol': 'AAPL',
#   'date': '2024-12-04',
#   'open': 242.87,
#   'high': 244.11,
#   'low': 241.25,
#   'close': 243.01,
#   'volume': 44383935,
#   'change': 0.14,
#   'changePercent': 0.05764401,
#   'vwap': 242.81},
#  {'symbol': 'AAPL',
#   'date': '2024-12-03',
#   'open': 239.81,
#   'high': 242.76,
#   'low': 238.9,
#   'close': 242.65,
#   'volume': 38861017,
#   'change': 2.84,
#   'changePercent': 1.18,
#   'vwap': 241.03},
#  {'symbol': 'AAPL',
#   'date': '2024-12-02',
#   'open': 237.27,
#   'high': 240.79,
#   'low': 237.16,
#   'close': 239.59,
#   'volume': 48137103,
#   'change': 2.32,
#   'changePercent': 0.97779,
#   'vwap': 238.7025},
#  {'symbol': 'AAPL',
#   'date': '2024-11-29',
#   'open': 234.81,
#   'high': 237.81,
#   'low': 233.97,
#   'close': 237.33,
#   'volume': 28481400,
#   'change': 2.53,
#   'changePercent': 1.07,
# ...
#   'high': 163.41,
#   'low': 159.41,
#   'close': 162.95,
#   'volume': 91454905,
#   'change': 1.47,
#   'changePercent': 0.91033,
#   'vwap': 161.8125},
#  {'symbol': 'AAPL',
#   'date': '2022-03-08',
#   'open': 158.82,
#   'high': 162.88,
#   'low': 155.8,
#   'close': 157.44,
#   'volume': 131148300,
#   'change': -1.38,
#   'changePercent': -0.86891,
#   'vwap': 158.735},
#  {'symbol': 'AAPL',
#   'date': '2022-03-07',
#   'open': 163.36,
#   'high': 165.02,
#   'low': 159.04,
#   'close': 159.3,
#   'volume': 96418845,
#   'change': -4.06,
#   'changePercent': -2.49,
#   'vwap': 161.68},
#  {'symbol': 'AAPL',
#   'date': '2022-03-04',
#   'open': 164.49,
#   'high': 165.55,
#   'low': 162.1,
#   'close': 163.17,
#   'volume': 83819592,
#   'change': -1.32,
#   'changePercent': -0.80248,
#   'vwap': 163.8275},
#  {'symbol': 'AAPL',
#   'date': '2022-03-03',
#   'open': 168.47,
#   'high': 168.91,
#   'low': 165.55,
#   'close': 166.23,
#   'volume': 76678441,
#   'change': -2.24,
#   'changePercent': -1.33,
#   'vwap': 167.29},
#  {'symbol': 'AAPL',
#   'date': '2022-03-02',
#   'open': 164.39,
#   'high': 167.36,
#   'low': 162.95,
#   'close': 166.56,
#   'volume': 79724800,
#   'change': 2.17,
#   'changePercent': 1.32,
#   'vwap': 165.315},
#  {'symbol': 'AAPL',
#   'date': '2022-03-01',
#   'open': 164.7,
#   'high': 166.6,
#   'low': 161.97,
#   'close': 163.2,
#   'volume': 83474425,
#   'change': -1.5,
#   'changePercent': -0.91075,
#   'vwap': 164.1175},
#  {'symbol': 'AAPL',
#   'date': '2022-02-28',
#   'open': 163.06,
#   'high': 165.42,
#   'low': 162.43,
#   'close': 165.12,
#   'volume': 95056629,
#   'change': 2.06,
#   'changePercent': 1.26,
#   'vwap': 164.0075},
#  {'symbol': 'AAPL',
#   'date': '2022-02-25',
#   'open': 163.84,
#   'high': 165.12,
#   'low': 160.87,
#   'close': 164.85,
#   'volume': 91974222,
#   'change': 1.01,
#   'changePercent': 0.61646,
#   'vwap': 163.67},
#  {'symbol': 'AAPL',
#   'date': '2022-02-24',
#   'open': 152.58,
#   'high': 162.85,
#   'low': 152,
#   'close': 162.74,
#   'volume': 141147540,
#   'change': 10.16,
#   'changePercent': 6.66,
#   'vwap': 157.5425},
#  {'symbol': 'AAPL',
#   'date': '2022-02-23',
#   'open': 165.54,
#   'high': 166.15,
#   'low': 159.75,
#   'close': 160.07,
#   'volume': 90009247,
#   'change': -5.47,
#   'changePercent': -3.3,
#   'vwap': 162.8775},
#  {'symbol': 'AAPL',
#   'date': '2022-02-22',
#   'open': 164.98,
#   'high': 166.69,
#   'low': 162.15,
#   'close': 164.32,
#   'volume': 91162800,
#   'change': -0.66,
#   'changePercent': -0.40005,
#   'vwap': 164.535},
#  {'symbol': 'AAPL',
#   'date': '2022-02-18',
#   'open': 169.82,
#   'high': 170.54,
#   'low': 166.19,
#   'close': 167.3,
#   'volume': 82772700,
#   'change': -2.52,
#   'changePercent': -1.48,
#   'vwap': 168.4625},
#  {'symbol': 'AAPL',
#   'date': '2022-02-17',
#   'open': 171.03,
#   'high': 171.91,
#   'low': 168.47,
#   'close': 168.88,
#   'volume': 69589344,
#   'change': -2.15,
#   'changePercent': -1.26,
#   'vwap': 170.0725},
#  {'symbol': 'AAPL',
#   'date': '2022-02-16',
#   'open': 171.85,
#   'high': 173.34,
#   'low': 170.05,
#   'close': 172.55,
#   'volume': 61177400,
#   'change': 0.7,
#   'changePercent': 0.40733,
#   'vwap': 171.9475},
#  {'symbol': 'AAPL',
#   'date': '2022-02-15',
#   'open': 170.97,
#   'high': 172.95,
#   'low': 170.25,
#   'close': 172.79,
#   'volume': 64286320,
#   'change': 1.82,
#   'changePercent': 1.06,
#   'vwap': 171.74},
#  {'symbol': 'AAPL',
#   'date': '2022-02-14',
#   'open': 167.37,
#   'high': 169.58,
#   'low': 166.56,
#   'close': 168.88,
#   'volume': 86185530,
#   'change': 1.51,
#   'changePercent': 0.90219,
#   'vwap': 168.0975},
#  {'symbol': 'AAPL',
#   'date': '2022-02-11',
#   'open': 172.33,
#   'high': 173.08,
#   'low': 168.04,
#   'close': 168.64,
#   'volume': 98670700,
#   'change': -3.69,
#   'changePercent': -2.14,
#   'vwap': 170.5225},
#  {'symbol': 'AAPL',
#   'date': '2022-02-10',
#   'open': 174.14,
#   'high': 175.48,
#   'low': 171.55,
#   'close': 172.12,
#   'volume': 90865900,
#   'change': -2.02,
#   'changePercent': -1.16,
#   'vwap': 173.3225},
#  {'symbol': 'AAPL',
#   'date': '2022-02-09',
#   'open': 176.05,
#   'high': 176.65,
#   'low': 174.9,
#   'close': 176.28,
#   'volume': 71285038,
#   'change': 0.23,
#   'changePercent': 0.13064,
#   'vwap': 175.97},
#  {'symbol': 'AAPL',
#   'date': '2022-02-08',
#   'open': 171.73,
#   'high': 175.35,
#   'low': 171.43,
#   'close': 174.83,
#   'volume': 74829217,
#   'change': 3.1,
#   'changePercent': 1.81,
#   'vwap': 173.335},
#  {'symbol': 'AAPL',
#   'date': '2022-02-07',
#   'open': 172.86,
#   'high': 173.95,
#   'low': 170.95,
#   'close': 171.66,
#   'volume': 77251204,
#   'change': -1.2,
#   'changePercent': -0.6942,
#   'vwap': 172.355},
#  {'symbol': 'AAPL',
#   'date': '2022-02-04',
#   'open': 171.68,
#   'high': 174.1,
#   'low': 170.68,
#   'close': 172.39,
#   'volume': 82465400,
#   'change': 0.71,
#   'changePercent': 0.41356,
#   'vwap': 172.2125},
#  {'symbol': 'AAPL',
#   'date': '2022-02-03',
#   'open': 174.48,
#   'high': 176.24,
#   'low': 172.12,
#   'close': 172.9,
#   'volume': 89418100,
#   'change': -1.58,
#   'changePercent': -0.90555,
#   'vwap': 173.935},
#  {'symbol': 'AAPL',
#   'date': '2022-02-02',
#   'open': 174.75,
#   'high': 175.88,
#   'low': 173.33,
#   'close': 175.84,
#   'volume': 84914300,
#   'change': 1.09,
#   'changePercent': 0.62375,
#   'vwap': 174.95},
#  {'symbol': 'AAPL',
#   'date': '2022-02-01',
#   'open': 174.01,
#   'high': 174.84,
#   'low': 172.31,
#   'close': 174.61,
#   'volume': 86213911,
#   'change': 0.6,
#   'changePercent': 0.34481,
#   'vwap': 173.9425},
#  {'symbol': 'AAPL',
#   'date': '2022-01-31',
#   'open': 170.16,
#   'high': 175,
#   'low': 169.51,
#   'close': 174.78,
#   'volume': 115541600,
#   'change': 4.62,
#   'changePercent': 2.72,
#   'vwap': 172.3625},
#  {'symbol': 'AAPL',
#   'date': '2022-01-28',
#   'open': 165.71,
#   'high': 170.35,
#   'low': 162.8,
#   'close': 170.33,
#   'volume': 179935700,
#   'change': 4.62,
#   'changePercent': 2.79,
#   'vwap': 167.2975},
#  {'symbol': 'AAPL',
#   'date': '2022-01-27',
#   'open': 162.45,
#   'high': 163.84,
#   'low': 158.28,
#   'close': 159.22,
#   'volume': 121954638,
#   'change': -3.23,
#   'changePercent': -1.99,
#   'vwap': 160.9475},
#  {'symbol': 'AAPL',
#   'date': '2022-01-26',
#   'open': 163.5,
#   'high': 164.39,
#   'low': 157.82,
#   'close': 159.69,
#   'volume': 108275308,
#   'change': -3.81,
#   'changePercent': -2.33,
#   'vwap': 161.35},
#  {'symbol': 'AAPL',
#   'date': '2022-01-25',
#   'open': 158.98,
#   'high': 162.76,
#   'low': 157.02,
#   'close': 159.78,
#   'volume': 115798400,
#   'change': 0.8,
#   'changePercent': 0.50321,
#   'vwap': 159.635},
#  {'symbol': 'AAPL',
#   'date': '2022-01-24',
#   'open': 160.02,
#   'high': 162.3,
#   'low': 154.7,
#   'close': 161.62,
#   'volume': 162706686,
#   'change': 1.6,
#   'changePercent': 0.99988,
#   'vwap': 159.66},
#  {'symbol': 'AAPL',
#   'date': '2022-01-21',
#   'open': 164.42,
#   'high': 166.33,
#   'low': 162.3,
#   'close': 162.41,
#   'volume': 122848900,
#   'change': -2,
#   'changePercent': -1.22,
#   'vwap': 163.865},
#  {'symbol': 'AAPL',
#   'date': '2022-01-20',
#   'open': 166.98,
#   'high': 169.68,
#   'low': 164.18,
#   'close': 164.51,
#   'volume': 91420515,
#   'change': -2.47,
#   'changePercent': -1.48,
#   'vwap': 166.3375},
#  {'symbol': 'AAPL',
#   'date': '2022-01-19',
#   'open': 170,
#   'high': 171.08,
#   'low': 165.94,
#   'close': 166.23,
#   'volume': 94815000,
#   'change': -3.77,
#   'changePercent': -2.22,
#   'vwap': 168.3125},
#  {'symbol': 'AAPL',
#   'date': '2022-01-18',
#   'open': 171.51,
#   'high': 172.54,
#   'low': 169.41,
#   'close': 169.8,
#   'volume': 91168729,
#   'change': -1.71,
#   'changePercent': -0.99703,
#   'vwap': 170.815},
#  {'symbol': 'AAPL',
#   'date': '2022-01-14',
#   'open': 171.34,
#   'high': 173.78,
#   'low': 171.09,
#   'close': 173.07,
#   'volume': 80440800,
#   'change': 1.73,
#   'changePercent': 1.01,
#   'vwap': 172.32},
#  {'symbol': 'AAPL',
#   'date': '2022-01-13',
#   'open': 175.78,
#   'high': 176.62,
#   'low': 171.79,
#   'close': 172.19,
#   'volume': 84505800,
#   'change': -3.59,
#   'changePercent': -2.04,
#   'vwap': 174.095},
#  {'symbol': 'AAPL',
#   'date': '2022-01-12',
#   'open': 176.12,
#   'high': 177.18,
#   'low': 174.82,
#   'close': 175.53,
#   'volume': 74805200,
#   'change': -0.59,
#   'changePercent': -0.335,
#   'vwap': 175.9125},
#  {'symbol': 'AAPL',
#   'date': '2022-01-11',
#   'open': 172.32,
#   'high': 175.18,
#   'low': 170.82,
#   'close': 175.08,
#   'volume': 76138312,
#   'change': 2.76,
#   'changePercent': 1.6,
#   'vwap': 173.35},
#  {'symbol': 'AAPL',
#   'date': '2022-01-10',
#   'open': 169.08,
#   'high': 172.5,
#   'low': 168.17,
#   'close': 172.19,
#   'volume': 106765600,
#   'change': 3.11,
#   'changePercent': 1.84,
#   'vwap': 170.485},
#  {'symbol': 'AAPL',
#   'date': '2022-01-07',
#   'open': 172.89,
#   'high': 174.14,
#   'low': 171.03,
#   'close': 172.17,
#   'volume': 86709147,
#   'change': -0.72,
#   'changePercent': -0.41645,
#   'vwap': 172.5575},
#  {'symbol': 'AAPL',
#   'date': '2022-01-06',
#   'open': 172.7,
#   'high': 175.3,
#   'low': 171.64,
#   'close': 172,
#   'volume': 96904000,
#   'change': -0.7,
#   'changePercent': -0.40533,
#   'vwap': 172.91},
#  {'symbol': 'AAPL',
#   'date': '2022-01-05',
#   'open': 179.61,
#   'high': 180.17,
#   'low': 174.64,
#   'close': 174.92,
#   'volume': 94537602,
#   'change': -4.69,
#   'changePercent': -2.61,
#   'vwap': 177.335},
#  {'symbol': 'AAPL',
#   'date': '2022-01-04',
#   'open': 182.63,
#   'high': 182.94,
#   'low': 179.12,
#   'close': 179.7,
#   'volume': 99310438,
#   'change': -2.93,
#   'changePercent': -1.6,
#   'vwap': 181.0975},
#  {'symbol': 'AAPL',
#   'date': '2022-01-03',
#   'open': 177.83,
#   'high': 182.88,
#   'low': 177.71,
#   'close': 182.01,
#   'volume': 104701220,
#   'change': 4.18,
#   'changePercent': 2.35,
#   'vwap': 180.1075},
#  {'symbol': 'AAPL',
#   'date': '2021-12-31',
#   'open': 178.09,
#   'high': 179.23,
#   'low': 177.26,
#   'close': 177.57,
#   'volume': 64062300,
#   'change': -0.515,
#   'changePercent': -0.29199,
#   'vwap': 178.0375},
#  {'symbol': 'AAPL',
#   'date': '2021-12-30',
#   'open': 179.47,
#   'high': 180.57,
#   'low': 178.09,
#   'close': 178.2,
#   'volume': 59773014,
#   'change': -1.27,
#   'changePercent': -0.70764,
#   'vwap': 179.0825},
#  {'symbol': 'AAPL',
#   'date': '2021-12-29',
#   'open': 179.33,
#   'high': 180.63,
#   'low': 178.14,
#   'close': 179.38,
#   'volume': 62348931,
#   'change': 0.05,
#   'changePercent': 0.02788156,
#   'vwap': 179.37},
#  {'symbol': 'AAPL',
#   'date': '2021-12-28',
#   'open': 180.16,
#   'high': 181.33,
#   'low': 178.53,
#   'close': 179.29,
#   'volume': 79144339,
#   'change': -0.87,
#   'changePercent': -0.4829,
#   'vwap': 179.8275},
#  {'symbol': 'AAPL',
#   'date': '2021-12-27',
#   'open': 177.09,
#   'high': 180.42,
#   'low': 177.07,
#   'close': 180.33,
#   'volume': 74919600,
#   'change': 3.25,
#   'changePercent': 1.83,
#   'vwap': 178.7275},
#  {'symbol': 'AAPL',
#   'date': '2021-12-23',
#   'open': 175.85,
#   'high': 176.85,
#   'low': 175.27,
#   'close': 176.28,
#   'volume': 68356600,
#   'change': 0.43,
#   'changePercent': 0.24453,
#   'vwap': 176.0625},
#  {'symbol': 'AAPL',
#   'date': '2021-12-22',
#   'open': 173.04,
#   'high': 175.86,
#   'low': 172.15,
#   'close': 175.64,
#   'volume': 92135303,
#   'change': 2.6,
#   'changePercent': 1.5,
#   'vwap': 174.1725},
#  {'symbol': 'AAPL',
#   'date': '2021-12-21',
#   'open': 171.56,
#   'high': 173.2,
#   'low': 169.12,
#   'close': 172.99,
#   'volume': 91185905,
#   'change': 1.44,
#   'changePercent': 0.83353,
#   'vwap': 171.7175},
#  {'symbol': 'AAPL',
#   'date': '2021-12-20',
#   'open': 168.28,
#   'high': 170.58,
#   'low': 167.46,
#   'close': 169.75,
#   'volume': 107499114,
#   'change': 1.47,
#   'changePercent': 0.87354,
#   'vwap': 169.0175},
#  {'symbol': 'AAPL',
#   'date': '2021-12-17',
#   'open': 169.93,
#   'high': 173.47,
#   'low': 169.69,
#   'close': 171.14,
#   'volume': 195923441,
#   'change': 1.21,
#   'changePercent': 0.71206,
#   'vwap': 171.0575},
#  {'symbol': 'AAPL',
#   'date': '2021-12-16',
#   'open': 179.28,
#   'high': 181.14,
#   'low': 170.75,
#   'close': 172.26,
#   'volume': 150185843,
#   'change': -7.02,
#   'changePercent': -3.92,
#   'vwap': 175.8575},
#  {'symbol': 'AAPL',
#   'date': '2021-12-15',
#   'open': 175.11,
#   'high': 179.5,
#   'low': 172.31,
#   'close': 179.3,
#   'volume': 131063300,
#   'change': 4.19,
#   'changePercent': 2.39,
#   'vwap': 176.555},
#  {'symbol': 'AAPL',
#   'date': '2021-12-14',
#   'open': 175.25,
#   'high': 177.74,
#   'low': 172.21,
#   'close': 174.33,
#   'volume': 139380400,
#   'change': -0.92,
#   'changePercent': -0.52496,
#   'vwap': 174.8825},
#  {'symbol': 'AAPL',
#   'date': '2021-12-13',
#   'open': 181.12,
#   'high': 182.13,
#   'low': 175.53,
#   'close': 175.74,
#   'volume': 153237019,
#   'change': -5.37,
#   'changePercent': -2.97,
#   'vwap': 178.63},
#  {'symbol': 'AAPL',
#   'date': '2021-12-10',
#   'open': 175.21,
#   'high': 179.63,
#   'low': 174.69,
#   'close': 179.45,
#   'volume': 115402731,
#   'change': 4.24,
#   'changePercent': 2.42,
#   'vwap': 177.245},
#  {'symbol': 'AAPL',
#   'date': '2021-12-09',
#   'open': 174.91,
#   'high': 176.75,
#   'low': 173.92,
#   'close': 174.56,
#   'volume': 108923739,
#   'change': -0.35,
#   'changePercent': -0.2001,
#   'vwap': 175.035},
#  {'symbol': 'AAPL',
#   'date': '2021-12-08',
#   'open': 172.13,
#   'high': 175.96,
#   'low': 170.7,
#   'close': 175.08,
#   'volume': 116998901,
#   'change': 2.96,
#   'changePercent': 1.71,
#   'vwap': 173.4675},
#  {'symbol': 'AAPL',
#   'date': '2021-12-07',
#   'open': 169.08,
#   'high': 171.58,
#   'low': 168.34,
#   'close': 171.18,
#   'volume': 120405400,
#   'change': 2.1,
#   'changePercent': 1.24,
#   'vwap': 170.045},
#  {'symbol': 'AAPL',
#   'date': '2021-12-06',
#   'open': 164.29,
#   'high': 167.88,
#   'low': 164.28,
#   'close': 165.32,
#   'volume': 107497000,
#   'change': 1.03,
#   'changePercent': 0.62694,
#   'vwap': 165.4425},
#  {'symbol': 'AAPL',
#   'date': '2021-12-03',
#   'open': 164.02,
#   'high': 164.96,
#   'low': 159.72,
#   'close': 161.84,
#   'volume': 118023116,
#   'change': -2.18,
#   'changePercent': -1.33,
#   'vwap': 162.635},
#  {'symbol': 'AAPL',
#   'date': '2021-12-02',
#   'open': 158.74,
#   'high': 164.2,
#   'low': 157.8,
#   'close': 163.76,
#   'volume': 136739200,
#   'change': 5.02,
#   'changePercent': 3.16,
#   'vwap': 161.125},
#  {'symbol': 'AAPL',
#   'date': '2021-12-01',
#   'open': 167.48,
#   'high': 170.3,
#   'low': 164.53,
#   'close': 164.77,
#   'volume': 152423003,
#   'change': -2.71,
#   'changePercent': -1.62,
#   'vwap': 166.77},
#  {'symbol': 'AAPL',
#   'date': '2021-11-30',
#   'open': 159.99,
#   'high': 165.52,
#   'low': 159.92,
#   'close': 165.3,
#   'volume': 174048100,
#   'change': 5.31,
#   'changePercent': 3.32,
#   'vwap': 162.6825},
#  {'symbol': 'AAPL',
#   'date': '2021-11-29',
#   'open': 159.37,
#   'high': 161.19,
#   'low': 158.79,
#   'close': 160.24,
#   'volume': 88748217,
#   'change': 0.87,
#   'changePercent': 0.5459,
#   'vwap': 159.8975},
#  {'symbol': 'AAPL',
#   'date': '2021-11-26',
#   'open': 159.57,
#   'high': 160.45,
#   'low': 156.36,
#   'close': 156.81,
#   'volume': 76959800,
#   'change': -2.75,
#   'changePercent': -1.73,
#   'vwap': 158.2975},
#  {'symbol': 'AAPL',
#   'date': '2021-11-24',
#   'open': 160.75,
#   'high': 162.14,
#   'low': 159.64,
#   'close': 161.94,
#   'volume': 69463623,
#   'change': 1.19,
#   'changePercent': 0.74028,
#   'vwap': 161.1175},
#  {'symbol': 'AAPL',
#   'date': '2021-11-23',
#   'open': 161.12,
#   'high': 161.8,
#   'low': 159.06,
#   'close': 161.41,
#   'volume': 96041900,
#   'change': 0.29,
#   'changePercent': 0.17999,
#   'vwap': 160.8475},
#  {'symbol': 'AAPL',
#   'date': '2021-11-22',
#   'open': 161.68,
#   'high': 165.7,
#   'low': 161,
#   'close': 161.02,
#   'volume': 117467900,
#   'change': -0.66,
#   'changePercent': -0.40821,
#   'vwap': 162.35},
#  {'symbol': 'AAPL',
#   'date': '2021-11-19',
#   'open': 157.65,
#   'high': 161.02,
#   'low': 156.53,
#   'close': 160.55,
#   'volume': 117305600,
#   'change': 2.9,
#   'changePercent': 1.84,
#   'vwap': 158.9375},
#  {'symbol': 'AAPL',
#   'date': '2021-11-18',
#   'open': 153.71,
#   'high': 158.67,
#   'low': 153.05,
#   'close': 157.87,
#   'volume': 137827700,
#   'change': 4.16,
#   'changePercent': 2.71,
#   'vwap': 155.825},
#  {'symbol': 'AAPL',
#   'date': '2021-11-17',
#   'open': 151,
#   'high': 155,
#   'low': 150.99,
#   'close': 153.49,
#   'volume': 88807000,
#   'change': 2.5,
#   'changePercent': 1.65,
#   'vwap': 152.62},
#  {'symbol': 'AAPL',
#   'date': '2021-11-16',
#   'open': 149.94,
#   'high': 151.49,
#   'low': 149.34,
#   'close': 151,
#   'volume': 59256210,
#   'change': 1.06,
#   'changePercent': 0.70695,
#   'vwap': 150.4425},
#  {'symbol': 'AAPL',
#   'date': '2021-11-15',
#   'open': 150.37,
#   'high': 151.88,
#   'low': 149.43,
#   'close': 150,
#   'volume': 59222803,
#   'change': -0.37,
#   'changePercent': -0.24606,
#   'vwap': 150.42},
#  ...]

# %%
# don't delete this cell, but do run it -- it is needed for the autograder tests

# public test for stock_history
history = stock_history('BYND', 2019, 6)

# public test for stock_stats
stats = stock_stats(history)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[185], line 4
#       1 # don't delete this cell, but do run it -- it is needed for the autograder tests
#       2
#       3 # public test for stock_history
# ----> 4 history = stock_history('BYND', 2019, 6)
#       6 # public test for stock_stats
#       7 stats = stock_stats(history)
#
# File c:\Users\sweek\Downloads\ucsd\ucsd_classes\fa25\dsc80\dsc80-2025-fa\labs\lab06\lab.py:109, in stock_history(ticker, year, month)
#     107 api_key = 'lXc6qZucwcvy741kF1HA6w6mRqv2inOo'
#     108 base_url = 'https://financialmodelingprep.com/stable/historical-price-eod/full?symbol={ticker}&apikey={api_key}'
# --> 109 df = pd.DataFrame(requests.get(base_url).json())
#     110 df['date'] = pd.to_datetime(df['date'])
#     111 return df[(df['date'].dt.year == year) & (df['date'].dt.month == month)].sort_values('date')
#
# File c:\Users\sweek\miniforge3\envs\dsc80\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\sweek\miniforge3\envs\dsc80\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\sweek\miniforge3\envs\dsc80\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\sweek\miniforge3\envs\dsc80\Lib\site-packages\pandas\core\internals\construction.py:667, in _extract_index(data)
#     664         raise ValueError("Per-column arrays must each be 1-dimensional")
#     666 if not indexes and not raw_lengths:
# --> 667     raise ValueError("If using all scalar values, you must pass an index")
#     669 if have_series:
#     670     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
grader.check("q3")

# %% [markdown]
# ## Question 4 – Comment Threads 🧵
#
# You regularly browse [Hacker News](https://news.ycombinator.com/) to keep up with the latest news in tech. One link to a Hacker News article is https://news.ycombinator.com/item?id=18344932. Note that this article has 18 comments and has a `storyid` of 18344932.
#
# The problem now is that you don't have internet access on your phone during your morning commute to work, so you want to save the interesting stories' comment threads beforehand in a CSV. You find their [API documentation](https://github.com/HackerNews/API) and decide to get to work.
#
# Complete the implementation of the function `get_comments`, which takes in a `storyid` and returns a DataFrame of all the comments below the news story. You can ignore "dead" comments(you will know them when you see them), as well as "dead" comments’ children. **Make sure the order of the comments in your DataFrame is from top to bottom just as you see on the website**.
#
# The DataFrame that `get_comments` returns should have 5 columns:
# 1. `'id'`: The unique ID of the comment.
# 2. `'by'`: The author of the comment.
# 3. `'text'`: The actual comment.
# 4. `'parent'`: The unique ID of the comment this comment is replying to.
# 5. `'time'`: When the comment was created (in `pd.Timestamp` format).
#
# Some guidance:
# 1. The URL to make requests to is `'https://hacker-news.firebaseio.com/v0/item/{}.json'`, however, the `{}` should be replaced with the ID of the article or page you are trying to access.
# 2. Again, do not `import json` – instead, use the `json` method on the Response object you get back.
# 3. Use depth-first search when traversing the comments tree. You will have to do this manually, since you cannot use Beautiful Soup (which is only for HTML documents, not JSON objects).
# 4. Make sure the length of your returned DataFrame is the same as value for the `'descendants'` key in the response JSON (both of which correspond to the number of comments for the story).
# 5. You are allowed to use loops in this function. You may also want to create at least one helper function.
#
# <div class="alert alert-block alert-success">
#     You may find <a href="https://www.youtube.com/watch?v=uOfwW-onmpc"><b>this hint video 🎥</b></a> helpful!
# </div>

# %%
# don't delete this cell, but do run it -- it is needed for the autograder tests
comments = get_comments(18344932)

# %%
grader.check("q4")

# %% [markdown]
# ## Congratulations! You're done Lab 6! 🏁
#
# As a reminder, all of the work you want to submit needs to be in `lab.py`.
#
# To ensure that all of the work you want to submit is in `lab.py`, we've included a script named `lab-validation.py` in the lab folder. You shouldn't edit it, but instead, you should call it from the command line (e.g. the Terminal) to test your work.
#
# Once you've finished the lab, you should open the command line and run, in the directory for this lab:
#
# ```
# python lab-validation.py
# ```
#
# **This will run all of the `grader.check` cells that you see in this notebook, but only using the code in `lab.py` – that is, it doesn't look at any of the code in this notebook. If all of your `grader.check` cells pass in this notebook but not all of them pass in your command line with the above command, then you likely have code in your notebook that isn't in your `lab.py`!**
#
# You can also use `lab-validation.py` to test individual questions. For instance,
#
# ```
# python lab-validation.py q1 q2 q4
# ```
#
# will run the `grader.check` cells for Questions 1, 2, and 4 – again, only using the code in `lab.py`. [This video](https://www.loom.com/share/0ea254b85b2745e59322b5e5a8692e91?sid=5acc92e6-0dfe-4555-9b6a-8115b6a52f99) how to use the script as well.
#
# Once `python lab-validation.py` shows that you're passing all test cases, you're ready to submit your `lab.py` (and only your `lab.py`) to Gradescope. Once submitting to Gradescope, make sure to stick around until all test cases pass.
#
# There is also a call to `grader.check_all()` below in _this_ notebook, but make sure to also follow the steps above.

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()
